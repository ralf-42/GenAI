# %% [markdown]
# <p><font size="7" color='grey'> <b>
# Anwendung Generativer KI
# </b></font> </br></p>

# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Modul 09: Lokale Modelle
# </b></font> </br></p>
#
#
# ---

# %% [markdown]
# # 1 | Übersicht
# ---
