# %% [markdown]
# <p><font size="7" color='grey'> <b>
# Anwendung Generativer KI
# </b></font> </br></p>

# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Modul 00: Kurs Intro
# </b></font> </br></p>
#
# ---

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/ralf-42/GenAI/blob/main/01%20ipynb/M00_Prolog.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # **1 <font color='orange'>|</font> Kursmodule**
# ---

# %% [markdown]
# + Die Basis-Module vermittelt alle wesentlichen Grundlagen und Werkzeuge für die praktische Arbeit mit Generativer KI.
# + Die Erweiterungsmodule werden je nach Interesse und Anwendungsbereich flexibel hinzuwählen.
# + Neben oder anstelle von LangChain können ggf. weitere/andere Frameworks (z.B. LLama Stack) verwendet werden.

# %% [markdown]
# | Modultyp    | Modul-Nr. | Titel                                 | Themen                                                                                                                                                                                                                                                                           | Relevanz                                                                                    |
# | ----------- | --------- | ------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------- |
# | Basis       | 1         | Einführung Generative AI              | • Kursüberblick<br>• Überblick Generative AI<br>• Einführung OpenAI<br>• Einführung Hugging Face<br>• Einführung LangChain                                                                                                                                                       | Fundamentales Verständnis der Gen-AI-Technologien als Grundlage für den Kurs.               |
# | Basis       | 2         | Grundlagen Modellansteuerung          | • Überblick Prompting, RAG, Fine-Tuning<br>• Einsatzszenarien<br>• Entscheidungskriterien<br>• Trade-offs                                                                                                                                                                        | Essentielles Verständnis der verschiedenen Ansätze zur Modellansteuerung.                   |
# | Basis       | 3         | Codieren mit GenAI                    | • Prompting für Codegenerierung<br>• Revisionsprompts<br>• Debugging mit LLMs<br>• Prozessintegration<br>• Grenzen der LLM-Codegenerierung                                                                                                                                       | Praktische Fähigkeiten für LLM-gestützte Programm-Entwicklung.                              |
# | Basis       | 4         | Large Language Models und Transformer | • Foundation Model<br>• Transformer-Architektur<br><mark style="background: #FF5582A6;">• Attention-Mechanismus<br>• Multi-Head Attention<br>• Encoder-Decoder Struktur</mark><br>• Textgenerierung<br>• Textzusammenfassung<br>• Textklassifizierung<br>• LLM schreibt ein Buch | Vertieftes Verständnis der Transformer-Architektur und LLM-Funktionsweise.                  |
# | Basis       | 5         | LangChain: Chat und Memory            | • LangChain-Konversationen<br>• Conversation Buffer Window Memory<br>• Conversation Token Buffer Memory<br>• Conversation Summary Memory<br>• Persisting Memory                                                                                                                  | Memory-Typen für Flexibilität und Skalierbarkeit, um Konversationen effizient zu verwalten. |
# | Basis       | 6         | LangChain: Datenextraktion            | • Structured Output Parser<br>• CSV/JSON/Pandas Parser<br>• Pydantic Parser<br>• Custom Output Parser<br>• Output-Fixing Parser                                                                                                                                                  | Parser-Typen für robuste und flexible Verarbeitung von Modellantworten.                     |
# | Basis       | 7         | Retrieval Augmented Generation        | • Einführung in RAG<br>• ChromaDB<br>• Embeddings<br>• Q&A über Dokumente<br>• Embedding-Datenbanken                                                                                                                                                                             | Schlüsseltechnologie für Informationsverarbeitung.                                          |
# | Basis       | 8         | Multimodal und Text-zu-Bild           | • Einführung in Multimodal und Text-zu-Bild<br>• DALL·E Bildgenerierung und -bearbeitung<br>• Multimodale Modelle<br>• Illustriertes Buch                                                                                                                                        | Erweiterung um visuelle Komponenten.                                                        |
# | Basis       | 9         | Lokale Modelle                        | • Installation und Setup lokaler Modelle Ollama, LMStudio<br>• Llama und andere LLMs<br>• Quantisierung und Optimierung<br>• Lokale Embeddings<br>• Vor- und Nachteile lokaler Modelle                                                                                           | Einsatz von KI-Modellen ohne Cloud-Abhängigkeit.                                            |
# | Basis       | 10        | Gradio                                | • Gradio in Google Colab<br>• Einführung in Gradio<br>• Verständnis des Gradio-Status<br>• Chat-Anwendung erstellen<br>• Erweiterte Chat-Anwendung                                                                                                                               | UI-Entwicklung für KI-Anwendungen.                                                          |
# | Erweiterung | 11        | LangChain: Agents                     | • Einführung in LangChain Agents<br>• Agent Tools<br>• Retrieval/Search Tools<br>• Konstruktion von Agents<br>• Benutzerdefinierte Agents                                                                                                                                        | Entwicklung autonomer KI-Systeme.                                                           |
# | Erweiterung | 12        | Modellauswahl und Evaluation          | • Modellvergleich<br>• Metriken<br>• Entscheidungskriterien<br>• Evaluation<br>• Best Practices                                                                                                                                                                                  | Fundierte Modellauswahl und Bewertung.                                                      |
# | Erweiterung | 13        | Fine-Tuning und Optimierung           | • Wann Feinabstimmung notwendig ist<br>• Datensatz vorbereiten<br>• OpenAI Feinabstimmung<br>• LoRA (Low-Rank Adaptation)<br>• Prefix Tuning<br>• Prompt Tuning<br>• Vergleich der Ansätze                                                                                       | Optimierung und effiziente Anpassung für spezifische Anwendungsfälle.                       |
# | Erweiterung | 14        | Advanced Prompt Engineering           | • Few Shot/Chain of Thought<br>• Persona-/Rollenmuster<br>• Verifizierungs-/Fragemuster<br>• Strukturierte Prompt-Muster<br>• Optimierungsstrategien                                                                                                                             | Fortgeschrittene Prompt-Strategien.                                                         |
# | Erweiterung | 15        | Sprachverarbeitung                    | • Sprachbasierte Chatbots<br>• Sprachgenerierung<br>• Spracherkennung<br>• Sprachbasierter Chatbot<br>• Trends in GenAI                                                                                                                                                          | Erschließung von Sprachanwendungen.                                                         |

# %% [markdown]
# # **2 <font color='orange'>|</font> Accounts & API-Keys**
# ---

# %% [markdown]
# + **Google:** Sie müssen sich bei Google anmelden und einen kostenlosen Google-Account erhalten, um mit Google Colab und Google Drive zu arbeiten.
# + **OpenAI:** Sie müssen sich bei OpenAI anmelden und einen OpenAI-Schlüssel erwerben und mit einer Zahlungsart verknüpfen. Rechnen Sie damit, für den Abschluss dieses Kurses etwa 5-10 EUR auszugeben.
# + **Hugging Face:** Sie müssen sich bei HuggingFace anmelden und einen kostenlosen Schlüssel erhalten, um bestimmte vortrainierte Modelle herunterzuladen.

# %% [markdown]
# [OpenAI](https://)
# [Hugging Face](https://)

# %% [markdown]
# # **3 <font color='orange'>|</font> Kursmaterial**
# ---

# %% [markdown]
# Verbindung zu Google Drive herstellen

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Im Verzeichnis `/content/drive/MyDrive/GenAI` auf Google Drive werden die Kursunterlagen angelegt.

# %%
# !rm -rf /content/drive/MyDrive/GenAI
# !git clone https://github.com/ralf-42/GenAI /content/drive/MyDrive/GenAI

# %% [markdown]
# # **4 <font color='orange'>|</font> Notebook speichern**
# ---

# %% [markdown]
# Datei | Kopie in Drive speichern
