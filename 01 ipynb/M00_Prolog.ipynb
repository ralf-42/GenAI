# %% [markdown]
# <p><font size="7" color='grey'> <b>
# Anwendung Generativer KI
# </b></font> </br></p>

# %% [markdown]
# <p><font size="6" color='grey'> <b>
# Modul 00: Prolog
# </b></font> </br></p>
#
# ---

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/ralf-42/GenAI/blob/main/01%20ipynb/M00_Prolog.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # **1 <font color='orange'>|</font> Kursmodule**
# ---

# %% [markdown]
# Die Basis-Module vermittelt alle wesentlichen Grundlagen und Werkzeuge für die praktische Arbeit mit Generativer KI. Die Erweiterungsmodule werden je nach Interesse und Anwendungsbereich flexibel hinzuwählen.

# %% [markdown]
# | Modultyp    | Modul-Nr. | Titel                            | Themen                                                                                                                                                                                  | Relevanz                                                                                    |
# | ----------- | --------- | -------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------- |
# | Basis       | 1         | Einführung in Generative AI      | • Kursüberblick<br>• Überblick über Generative AI<br>• Einführung OpenAI<br>• Einführung Hugging Face<br>• Einführung in LangChain<br>• Prompt Engineering                              | Fundamentales Verständnis der Gen-AI-Technologien als Grundlage für den Kurs.               |
# | Basis       | 2         | Grundlagen der Modellansteuerung | • Überblick Prompting, RAG, Fine-Tuning<br>• Einsatzszenarien<br>• Entscheidungskriterien<br>• Trade-offs                                                                               | Essentielles Verständnis der verschiedenen Ansätze zur Modellansteuerung.                   |
# | Basis       | 3         | Promptbasierte Entwicklung       | • Prompting für Codegenerierung<br>• Revisionsprompts<br>• Debugging mit LLMs<br>• Prompts in Softwareentwicklung<br>• Grenzen der LLM-Codegenerierung                                  | Praktische Fähigkeiten für LLM-gestützte Entwicklung.                                       |
# | Basis       | 4         | Large Language Models            | • Grundlagenmodelle<br>• Textgenerierung<br>• Textzusammenfassung<br>• Textklassifizierung<br>• LLM schreibt ein Buch                                                                   | Vertieftes Verständnis der LLM-Funktionsweise.                                              |
# | Basis       | 5         | LangChain: Chat und Memory       | • LangChain-Konversationen<br>• Conversation Buffer Window Memory<br>• Conversation Token Buffer Memory<br>• Conversation Summary Memory<br>• Persisting Memory                         | Memory-Typen für Flexibilität und Skalierbarkeit, um Konversationen effizient zu verwalten. |
# | Basis       | 6         | LangChain: Datenextraktion       | • Structured Output Parser<br>• CSV/JSON/Pandas Parser<br>• Pydantic Parser<br>• Custom Output Parser<br>• Output-Fixing Parser                                                         | Parser-Typen für robuste und flexible Verarbeitung von Modellantworten.                     |
# | Basis       | 7         | Retrieval-Augmented Generation   | • Einführung in RAG<br>• ChromaDB<br>• Embeddings<br>• Q&A über Dokumente<br>• Embedding-Datenbanken                                                                                    | Schlüsseltechnologie für Informationsverarbeitung.                                          |
# | Basis       | 8         | Multimodal und Text-zu-Bild      | • Einführung in Multimodal und Text-zu-Bild<br>• DALL·E Bildgenerierung und -bearbeitung<br>• Multimodale Modelle<br>• Illustriertes Buch                                               | Erweiterung um visuelle Komponenten.                                                        |
# | Basis       | 9         | Lokale Modelle                   | • Installation und Setup lokaler Modelle Ollama, LMStudio<br>• Llama und andere LLMs <br>• Quantisierung und Optimierung<br>• Lokale Embeddings<br>• Vor- und Nachteile lokaler Modelle | Grundlagen für den Einsatz von KI-Modellen ohne Cloud-Abhängigkeit.                         |
# | Basis       | 10        | Gradio                           | • Gradio in Google Colab<br>• Einführung in Gradio<br>• Verständnis des Gradio-Status<br>• Chat-Anwendung erstellen<br>• Erweiterte Chat-Anwendung                                      | UI-Entwicklung für KI-Anwendungen.                                                          |
# | Erweiterung | 11        | LangChain: Agents                | • Einführung in LangChain Agents<br>• Agent Tools<br>• Retrieval/Search Tools<br>• Konstruktion von Agents<br>• Benutzerdefinierte Agents                                               | Entwicklung autonomer KI-Systeme.                                                           |
# | Erweiterung | 12        | Modellauswahl und Evaluation     | • Modellvergleich<br>• Metriken<br>• Entscheidungskriterien<br>• Evaluation                                                                                                             | Fundierte Modellauswahl und Bewertung.                                                      |
# | Erweiterung | 13        | Fine-Tuning                      | • Wann Feinabstimmung notwendig ist<br>• Datensatz vorbereiten<br>• OpenAI Feinabstimmung<br>• Anwendung und Bewertung der Feinabstimmung                                               | Optimierung für spezifische Anwendungsfälle.                                                |
# | Erweiterung | 14        | Advanced Prompt Engineering      | • Few Shot/Chain of Thought<br>• Persona-/Rollenmuster<br>• Verifizierungs-/Fragemuster<br>• Strukturierte Prompt-Muster                                                                | Fortgeschrittene Prompt-Strategien.                                                         |
# | Erweiterung | 15        | Sprachverarbeitung               | • Sprachbasierte Chatbots<br>• Sprachgenerierung/-erkennung mit OpenAI<br>• Sprachbasierter Chatbot<br>• Zukünftige Richtungen in GenAI                                                 | Erschließung von Sprachanwendungen.                                                         |

# %% [markdown]
# # **2 <font color='orange'>|</font> Kursorganisation**
# ---

# %% [markdown]
# | Kategorie | Details |
# |-----------|----------|
# | Zeitplanung | - 5 Tage <br>- Start: 09:00 Uhr <br>- Ende: 16:30 Uhr <br>- Pause nach 90 Min |
# | Vorgehen | - Grundlagen/Basiswissen <br>- Beispiele <br>- Training/Fallstudien <br>- Abschlussprojekt |
# | Verschiedenes | - Pinboard |

# %% [markdown]
# # **3 <font color='orange'>|</font> Pinboard**
# ---

# %% [markdown]
# <p><font color='black' size="7">
# Link: https://bit.ly/3T2evF6
# </font></p>

# %% [markdown]
# ![Screenshot 2025-01-06 173030.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# [Pinboard](https://bit.ly/3T2evF6)

# %% [markdown]
# # **4 <font color='orange'>|</font> IT-Setup**
# ---

# %% [markdown]
# ![Screenshot 2025-01-06 184052.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **5 <font color='orange'>|</font> Entwicklungsprozess**
# ---

# %% [markdown]
# ![Bild1.png](data:image/png;base64,...)

# %% [markdown]
# Bild mit napkin.ai erstellt

# %% [markdown]
# # **6 <font color='orange'>|</font> Accounts & API-Keys**
# ---

# %% [markdown]
# + Google: Sie müssen sich bei Google anmelden und einen kostenlosen Google-Account erhalten, um mit Google Colab und Google Drive zu arbeiten.
# + Hugging Face: Sie müssen sich bei HuggingFace anmelden und einen kostenlosen Schlüssel erhalten, um bestimmte vortrainierte Modelle herunterzuladen.
# + OpenAI: Sie müssen sich bei OpenAI anmelden und einen OpenAI-Schlüssel erwerben und eine Kreditkarte verknüpfen. Rechnen Sie damit, für den Abschluss dieses Kurses etwa 5-10 EUR auszugeben.

# %% [markdown]
# [OpenAI](https://)
# [Hugging Face](https://)

# %% [markdown]
# # **7 <font color='orange'>|</font> Kursmaterial**
# ---

# %% [markdown]
# Verbindung zu Google Drive herstellen

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Im Verzeichnis `/content/drive/MyDrive/GenAI` auf Google Drive werden die Kursunterlagen angelegt.

# %%
# !rm -rf /content/drive/MyDrive/GenAI
# !git clone https://github.com/ralf-42/GenAI /content/drive/MyDrive/GenAI
