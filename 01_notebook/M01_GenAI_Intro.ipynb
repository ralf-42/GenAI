# %% [markdown]
# <p><font size="6" color='grey'> <b>
#
# Generative KI. Verstehen. Anwenden. Gestalten.
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# Einführung in Generative AI
# </b></font> </br></p>
#
# ---

# %%
#@title 🔧 Umgebung einrichten{ display-mode: "form" }
# !uv pip install --system -q git+https://github.com/ralf-42/GenAI.git#subdirectory=04_modul

from genai_lib.utilities import (
    check_environment,
    get_ipinfo,
    setup_api_keys,
    mprint,
    install_packages,
    mermaid,
    get_model_profile,
    extract_thinking,
    load_prompt
)

print()
check_environment()
print()
get_ipinfo()
# Out:
# Python Version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
# Installierte LangChain- und LangGraph-Bibliotheken:
# langchain                                1.2.12
# langchain-chroma                         1.1.0
# langchain-classic                        1.0.3
# langchain-community                      0.4.1
# langchain-core                           1.2.19
# langchain-ollama                         1.0.1
# langchain-openai                         1.1.11
# langchain-text-splitters                 1.1.1
# langgraph                                1.1.2
# langgraph-checkpoint                     4.0.1
# langgraph-prebuilt                       1.0.8
# langgraph-sdk                            0.3.11
#
# IP-Adresse: 34.138.173.218
# Hostname: 218.173.138.34.bc.googleusercontent.com
# Stadt: North Charleston
# Region: South Carolina
# Land: US
# Koordinaten: 32.8546,-79.9748
# Provider: AS396982 Google LLC
# Postleitzahl: 29415
# Zeitzone: America/New_York

# %% [markdown]
# # 1 | Überblick GenAI
# ---

# %% [markdown]
# Generative Künstliche Intelligenz (GenAI) bezeichnet KI-Modelle, die in der Lage sind, eigenständig **neue Inhalte** zu erzeugen – dazu zählen Texte, Bilder, Audio- und Videoformate. Diese Modelle basieren meist auf sogenannten **Foundation Models**, insbesondere **Large Language Models (LLMs)** wie GPT oder Claude, die durch das Training auf großen Datenmengen gelernt haben, Muster zu erkennen und kreative Inhalte zu generieren.

# %% [markdown]
# Multimodale Inhalte – Ein Überblick:
#
# * **Text**: Erstellung von Texten, Zusammenfassungen, Übersetzungen, Code und interaktive Dialoge (z. B. Chatbots, Assistenten).
# * **Bild**: Generierung von Bildern aus Textbeschreibungen (z. B. DALL·E, Midjourney), Bearbeitung bestehender Bilder (Inpainting/Outpainting), Klassifikation und Objekt-Erkennung.
# * **Audio**: Umwandlung von Sprache in Text (Speech-to-Text), umgekehrt (Text-to-Speech), Klanganalysen, Podcasts und Musikkomposition.
# * **Video**: Automatische Videoerstellung aus Text, Videoanalyse, Bild-zu-Video-Transformation und Erkennung von Inhalten in Videos.
#
# Im Laufe dieses Kurses werden Sie sowohl textbasierte als auch multimodale Modelle kennenlernen, praxisnah einsetzen und kritisch reflektieren. Ziel ist es, ein fundiertes Verständnis für die Potenziale und Grenzen generativer KI-Technologien zu entwickeln.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ralf-42/GenAI/main/07_image/genai_ueberblick.png" width="800" alt="Avatar">

# %% [markdown]
# <p><font color='black' size="5">
# Problemklassen
# </font></p>

# %% [markdown]
# Diese Tabelle dient als Orientierungshilfe. Sie beantwortet nicht die Frage „Welches Tool ist das beste?“, sondern die wichtigere Frage:
#
# > Welche Art von Problem habe ich – und welcher Lösungsweg passt grundsätzlich dazu?
#
# In der Praxis scheitern viele KI-Projekte nicht am Modell, sondern daran, dass Chat, Workflow, Code oder Agenten für das falsche Problem eingesetzt werden. Die Tabelle ordnet typische GenAI-Szenarien nach Problemklassen und zeigt einen sinnvollen Startpunkt, nicht die endgültige Architektur.

# %% [markdown]
# | Problemklasse | Typisches Szenario | Woran erkennt man das? | Empfohlener Start | Typischer Anfängerfehler |
# |---|---|---|---|---|
# | Kreativer Assistent | „Ich brauche Ideen, Texte oder Erklärungen.“ | Einmalig, interaktiv, Mensch denkt mit | Chat / Copilot | Zu früh automatisieren oder integrieren wollen |
# | Prozess-Automatisierer | „Das Gleiche passiert immer wieder nach einem klaren Auslöser.“ | Wiederholbar, fester Trigger, wenig Logik | Workflow (Make / n8n) | Workflows für komplexe Logik missbrauchen |
# | Daten-Verarbeiter | „Viele Dateien oder Datensätze müssen systematisch ausgewertet werden.“ | Große Menge, Schleifen, Kosten relevant | Python + API | Alles per Chat oder Workflow lösen wollen |
# | Autonomer Entwickler | „Die KI soll selbstständig mit Code oder Dateien arbeiten.“ | Kontext über mehrere Schritte, Exploration | Agent (z. B. Code-Agent) | Agenten einsetzen, wo ein Script reicht |
# | App-Bauer (intern) | „Andere sollen das regelmäßig nutzen.“ | UI nötig, Wissensbasis, stabiler Betrieb | KI-App-Builder | Chat als Produkt missverstehen |
# | Datenschützer | „Ich muss Patientendaten analysieren, die das Haus nicht verlassen dürfen.“ | Sensible Daten, rechtliche Vorgaben, kein Cloud-Zugriff | Lokale LLMs (z. B. Ollama) | Datenschutz nur als Hosting-Frage sehen |

# %% [markdown]
# <p><font color='black' size="5">
# API - Application Programming Interface
# </font></p>

# %% [markdown]
# Eine API ist eine Art "Brücke" oder Schnittstelle, über die verschiedene Programme oder Software-Komponenten miteinander kommunizieren können – ohne dass sie genau wissen müssen, wie die andere Seite im Detail funktioniert.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ralf-42/GenAI/main/07_image/API_Key.png" class="logo" width="480"/>

# %% [markdown]
# # 2 | Einführung OpenAI
# ---

# %% [markdown]
# <img src="https://chatopenai.de/wp-content/uploads/2025/01/chatgpt_logo-2-150x150.jpg" class="logo" width="120"/>

# %% [markdown]
# OpenAI ist ein Forschungsunternehmen im Bereich der künstlichen Intelligenz, das darauf abzielt,  KI-Technologien zu entwickeln und zu fördern. Gegründet wurde es im Dezember 2015 von Elon Musk, Sam Altman und anderen, mit dem Ziel, positive menschliche Auswirkungen zu maximieren und sicherzustellen, dass KI-Entwicklungen breit verteilt und nicht von wenigen beherrscht werden. OpenAI ist bekannt für seine fortschrittlichen KI-Modelle, darunter GPT (Generative Pre-trained Transformer) und DALL-E, die in einer Vielzahl von Anwendungen eingesetzt werden, von Sprachverarbeitung bis hin zu Bildgenerierung.

# %% [markdown]
# [The Hidden AI Workforce: 29% of Employees Pay for Their Own AI Tools While Bosses Provide No Training](https://explodingtopics.com/blog/ai-workforce-research#ai-more-popular-at-home-than-at-work)

# %% [markdown]
# [... Toolnutzung](https://cdn.buttercms.com/output=f:webp/pzdabRqR36wTNA8bKeTp)

# %% [markdown]
# [... Aufgaben](https://cdn.buttercms.com/output=f:webp/kQ7C1EUQomk3kr92FdCt)

# %% [markdown]
# Im Kurs wird vorausgesetzt, dass die Teilnehmer:innen ein OpenAI-Konto einrichten und einen eigenen API-Key erstellen, der als eindeutige Kennung den Zugriff auf die Programmierschnittstellen von OpenAI ermögliche. Der API-Key fungiere wie ein Passcode und gewährleiste eine sichere Kommunikation zwischen den eigenen Anwendungen und den Diensten von OpenAI.

# %% [markdown]
# <p><font color='black' size="5">
# API-Key erstellen
# </font></p>

# %% [markdown]
# Man kann über die folgende URL auf OpenAI zugreifen und sich registrieren.
#
# + Anmelden/Registrieren: https://platform.openai.com/docs/overview
# + Nach Anmeldung sieht man die vertikale Optionsleiste links.
# + Auswahl des Zahnrads ⚙️ `Settings`
# + Auswahl `API Keys` (linke Navigationsleiste).
# + Auswahl `Create new secret key`.
# + Permissions `All`
# + Payment Methods hinterlegen

# %% [markdown]
# <p><font color='black' size="5">
# API-Key sichern
# </font></p>

# %% [markdown]
# Sichern des API-Keys in Colab.
#
# **Schritte:**
#
#
#
# + Im Jupyter-Notebook linke Navgationsleiste `Secrets` mit dem 🗝️-Symbol
# + Neues Secret hinzufügen
# + Namen vergeben und API-Key als Wert hinterlegen
# + Die Einträge sind **privat** und nur für den Account und für **ausgewählten Notebooks** sichtbar.

# %% [markdown]
# <p><font color='darkblue' size="4">
# ✨ <b>Empfehlung:</b>
# </font></p>
#
# Speichern des API-Keys unter den Namen: `OPENAI_API_KEY`. Der Name `OPENAI_API_KEY` ist der zumeist erwartete Umgebungsvariablenname in vielen Tools und Bibliotheken.

# %% [markdown]
# <p><font color='black' size="5">
# API-Key testen
# </font></p>

# %%
setup_api_keys(['OPENAI_API_KEY'], create_globals=False)

# %%
from openai import models

try:
    models = models.list()  # Note the lowercase 'models'
    print("✅ OpenAI API-Key ist gültig!")
    # for model in models.data:
    #     print(model) # This prints the entire model object.  You can access individual attributes like model.id

except Exception as e:  # Catch other potential errors
    print("❌ OpenAI API-Key ungültig!")
    print(f"An error occurred: {e}")

# %% [markdown]
# <p><font color='black' size="5">
# OpenAI Konversationsformat
# </font></p>

# %% [markdown]
# OpenAI bietet ein Konversationsformat für die Nutzung seiner Sprachmodelle, insbesondere für die Interaktion mit Chatbot-artigen Anwendungen. Dieses Format wird typischerweise in der ChatCompletion-API verwendet, die speziell für dialogorientierte Aufgaben entwickelt wurde. Die API erleichtert die Strukturierung von Dialogen, indem sie die Verwendung von rollenbasierten Nachrichten unterstützt, um den Kontext und die Intentionen der Beteiligten klar zu definieren.
#
# Grundprinzipien des Konversationsformats von OpenAI:
# In der Chat-API von OpenAI besteht ein Dialog aus einer Serie von Nachrichten, die jeweils einer Rolle zugeordnet sind. Die Hauptrollen sind:
#
# + **system**: Definiert den **Kontext** oder die Anweisungen für das Modell.
# + **user**: Enthält die **Benutzer**eingaben.
# + **assistant**: Die vom **Modell** generierten Antworten.

# %%
from openai import OpenAI, chat

model_name = 'gpt-4o-mini'
temperature = 0.2

client = OpenAI()

response = chat.completions.create(
  model=model_name,
  temperature=temperature,
  messages=[
    {"role": "system", "content": "Du bist ein hilfreicher KI-Assistent."},
    {"role": "user", "content": "Generative KI ist ..."}
  ]
)

mprint('## 🤖 KI:')
mprint(response.choices[0].message.content)

# %% [markdown]
# # 3 | Erste Orientierung Hugging Face
# ---

# %% [markdown]
# <img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" class="logo" width="120"/>

# %% [markdown]
# Hugging Face ist ein Unternehmen, das sich auf die Schaffung und Bereitstellung von Technologien im Bereich der künstlichen Intelligenz spezialisiert hat, insbesondere auf natürliche Sprachverarbeitung (NLP). Es wurde 2016 gegründet und ist vor allem für seine „Transformers“-Bibliothek bekannt, die eine breite Palette von vortrainierten Modellen wie BERT, GPT, T5 und anderen bietet, die für Aufgaben wie Textklassifikation, Übersetzung, Zusammenfassung und Frage-Antwort-Systeme verwendet werden können.
#
# Hugging Face betreibt auch eine Plattform, auf der die Community Modelle teilen und zusammenarbeiten kann. Diese Plattform ermöglicht es Forschern, Entwicklern und Unternehmen, Modelle zu finden, zu testen und einzusetzen. Darüber hinaus bietet Hugging Face Tools und Dienstleistungen für das Training, Hosting und die Verwaltung von KI-Modellen, einschließlich einer Modellhub-API, die den Zugriff auf tausende von Modellen ermöglicht.
#
# Das Unternehmen setzt stark auf Open-Source- und Community-basierten Ansätze, um die Entwicklung und Verbreitung von KI-Technologien zu demokratisieren und sicherzustellen, dass diese Technologien breit und ethisch angewendet werden.
#
#
# Für den Kurs ist es wichtig zu wissen, dass Hugging Face
# + den Zugang zu modernsten KI-Modellen vereinfacht und
# + ständig neue Modelle bereitstellt und die Plattform sowohl für
# + Anfänger als auch für Fortgeschrittene geeignet ist.

# %% [markdown]
# <p><font color='black' size="5">
# API-Key erstellen
# </font></p>

# %% [markdown]
# Schritte zum Erstellen des API-Keys:
#
# + Nach dem Login oben rechts auf das Profilbild klicken.
#
# + Auswahl `Settings` im Dropdown-Menü.
#
# + In der linken Seitenleiste den Menüpunkt `Access Tokens` auswählen.
#
# + Klick auf `New token`.
#
# + Einen Namen vergeben, empfohlen `HF_TOKEN`.
#
# + Token Type: `READ` (für reine Nutzung reicht meist *Read*).
#
# + Klick auf "Generate token".
#
# + Der erzeugte Token wird einmalig angezeigt – jetzt kopieren und sicher speichern.

# %% [markdown]
# <p><font color='darkblue' size="4">
# ✨ <b>Empfehlung:</b>
# </font></p>
#
# Speichern des API-Keys unter den Namen: `HF_TOKEN`. Der Name `HF_TOKEN` ist der zumeist erwartete Umgebungsvariablenname in vielen Tools und Bibliotheken.

# %% [markdown]
# <p><font color='black' size="5">
# API-Key testen
# </font></p>

# %%
setup_api_keys(['HF_TOKEN'], create_globals=False)

# %%
from huggingface_hub import HfApi

try:
    api = HfApi()
    api.whoami()
    print("✅ Hugging Face API-Key ist gültig!")

except Exception as e:
    print("❌ Hugging Face API-Key ungültig!")
    print(f"Fehlermeldung: {str(e)}")

# %% [markdown]
# <p><font color='black' size="5">
# Einfaches Beispiel Hugging Face
# </font></p>

# %% [markdown]
# `install_packages` ist eine Python-Installationsfunktio im Modul `genai_lib.utilities`.

# %%
install_packages(['sacremoses'])

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Laden eines Modells für Übersetzung (Englisch → Deutsch)
model_name = "Helsinki-NLP/opus-mt-en-de"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Text zum Übersetzen
text_to_translate = "Why is the sky blue?"

# Übersetzung durchführen
inputs = tokenizer(text_to_translate, return_tensors="pt")
outputs = model.generate(**inputs)
translation = tokenizer.decode(outputs[0], skip_special_tokens=True)

# Ergebnis anzeigen
mprint('## 🤖 KI:')
mprint(translation)

# %% [markdown]
# # 4 | Warm-up LangChain
# ---

# %% [markdown]
# <img src="https://images.seeklogo.com/logo-png/61/2/langchain-icon-logo-png_seeklogo-611655.png" class="logo" width="180"/>

# %% [markdown]
# LangChain ist ein Software-Framework, das darauf abzielt, die *Entwicklung* von Sprachanwendungen zu **vereinfachen**, indem es Werkzeuge zur Integration von Sprachmodellen mit externen Datenquellen und Diensten bietet. Es ist speziell darauf ausgerichtet, die Fähigkeiten von Large Language Models (LLMs) wie OpenAI's GPT-x zu nutzen und diese Modelle effektiv mit anderen Systemen zu verknüpfen, um praktische und funktionale Anwendungen zu erstellen.
#
# Das Framework bietet eine Reihe von Funktionen, darunter:
# - **Chain-of-Thought Prompting**: Dies hilft, die Antworten von Sprachmodellen zu verbessern, indem es den Denkprozess strukturiert, der in den Antworten enthalten ist.
# - **Retrieval-Augmented Generation (RAG)**: Eine Methode, die es ermöglicht, externe Informationen während der Generierung von Antworten dynamisch abzurufen, um die Genauigkeit und Relevanz der Antworten zu verbessern.
# - **Modulare Architektur**: LangChain ermöglicht es Entwicklern, verschiedene Komponenten wie Suchmaschinen, Datenbanken und andere Dienste einfach zu integrieren und zu kombinieren, um komplexe Anwendungen zu erstellen.
#
# Das Framework unterstützt die Erstellung von Anwendungen, die über einfache Textgenerierung hinausgehen und tieferes Verständnis und Interaktionen ermöglichen, indem es die Vorteile von Large Language Models mit spezifischen, aufgabenorientierten Informationen verbindet.

# %% [markdown]
# **Das LangChain-Ökosystem** verbindet Modell-Orchestrierung, Agenten-Workflows, Integrationen und Observability in einer Toolchain.

# %%
diagram = """
graph TD
    %% Definition der Stile für die einzelnen Boxen
    classDef ecosystem fill:#1565c0,stroke:#0d47a1,stroke-width:2px,color:#ffffff;
    classDef core fill:#0d47a1,stroke:#002171,stroke-width:2px,color:#ffffff;
    classDef greyBox fill:#A9A9A9,stroke:#707070,stroke-width:2px,color:#000000;

    subgraph Development ["<b>Entwicklung & Logik</b>"]
        LC_Core["<b>LangChain</b><br/>Basis & LCEL"]
        LC_Comm["<b>langchain-community</b><br/>Integrationen"]
        LC_Partner["<b>Partner-Pakete</b><br/>(OpenAI, etc.)"]
        LG["<b>LangGraph</b><br/>Workflows & Agenten"]
    end

    subgraph Observability ["<b>Qualität & Monitoring</b>"]
        LS["<b>LangSmith</b><br/>Tracing & Testing"]
    end

    subgraph Deployment ["<b>Bereitstellung</b>"]
        LGP["<b>LangSmith Deployment</b><br/>HF-Spaces (kostenlos)"]
    end

    %% Styling der Subgraphs (Hintergrund-Boxen)
    style Development fill:#e3f2fd,stroke:#1565c0,stroke-width:1px,stroke-dasharray: 5 5
    style Observability fill:#f3e5f5,stroke:#7b1fa2,stroke-width:1px,stroke-dasharray: 5 5
    style Deployment fill:#f5f5f5,stroke:#9e9e9e,stroke-width:1px

    %% Verbindungen
    LC_Core --> LC_Comm
    LC_Core --> LC_Partner
    LC_Core --> LG

    LG --> LS
    LC_Core --> LS

    LC_Core --> LGP
    LG --> LGP

    %% Klassen zuweisen
    class LC_Core core
    class LC_Comm,LC_Partner,LG,LS ecosystem
    class LGP greyBox
"""

mermaid(diagram, width=750)

# %% [markdown]
# <p><font color='black' size="5">
# Eine einzelne Frage stellen
# </font></p>

# %% [markdown]
# Um dem Modell eine einzelne, von vorherigen Dialogen unabhängige Frage zu stellen, kann eine Zeichenfolge als Eingabe verwendet werden, auf die das Modell direkt reagiert.

# %%
from langchain.chat_models import init_chat_model

# LLM initialisieren (Kurznotation: "provider:model")
llm = init_chat_model("openai:gpt-4o-mini", temperature=0.0)

# Definieren der Frage
user_input = "Was sind die fünf grössten Städte in Deutschland?"

# Aufruf des LLMs
response = llm.invoke(user_input)

# Ausgabe der Antwort
mprint("## ✨ Model response:")
mprint("---")
mprint(response.content)

# %% [markdown]
# <p><font color='black' size="5">
# Überblick LangChain Konzepte
# </font></p>

# %% [markdown]
# Konzepte von LangChain sind grundlegende Bausteine und Prinzipien, die das Framework ausmachen und seine Funktionsweise ermöglichen. Hier sind einige der wichtigsten Konzepte:
#
# + Chat-Modelle (**Chat models**): LLMs, die über eine Chat-API verfügbar sind und Sequenzen von Nachrichten verarbeiten1.
# + Nachrichten (**Messages**): Kommunikationseinheiten in Chat-Modellen für Ein- und Ausgabe1.
# + Chat-Verlauf (**Chat history**): Eine Sequenz von Nachrichten, die eine Konversation darstellt.
# + Tools (**Tools**): Funktionen mit definierten Schemata für Name, Beschreibung und Argumente.
# + Strukturierte Ausgabe (**Structured output**): Technik, um Chat-Modelle in strukturierten Formaten antworten zu lassen.
# + Retrieval Augmented Generation (**RAG**): Technik zur Verbesserung von Sprachmodellen durch Kombination mit externen Wissensbasen.
# + Prompt-Vorlagen (**Prompt template**s): Komponenten zur Erstellung strukturierter Prompts für LLMs.
# + Chains (**Chains**): Verknüpfungen mehrerer LLMs oder anderer Komponenten für komplexere Anwendungen.
# + Agenten (**Agents**): Nutzen Sprachmodelle, um Aktionssequenzen auszuwählen und mit externen Ressourcen zu interagieren.
# + Retriever (**Retriever**): Komponenten, die relevante Dokumente aus einer Wissensbasis abrufen.

# %% [markdown]
# <p><font color='darkgreen' size="4">
# 📋 <b>Quick-Template für Übungsaufgaben</b>
# </font></p>
#
# Für alle Übungsaufgaben steht ein **Quick-Template** zur Verfügung:
#
# > **`quick_template.ipynb`** — enthält die Standard-Umgebung (Setup, API-Keys, Imports) als fertigen Startpunkt. Einfach öffnen, kopieren und loslegen — kein Boilerplate von Grund auf neu schreiben.
#
# **Tipp für Google Colab:**
# > In Google Colab steht **Gemini** direkt als KI-Assistent zur Verfügung (Seitenleiste → ✨). Ideal zum Erkunden von Code-Varianten, Verstehen von Fehlermeldungen oder als Ideengeber für eigene Lösungsansätze.
