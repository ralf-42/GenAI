# %% [markdown]
# <p><font size="6" color='grey'> <b>
#
# Generative KI. Verstehen. Anwenden. Gestalten.
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# Kurs Intro
# </b></font> </br></p>
#
# ---

# %%
#@title 🔧 Umgebung einrichten{ display-mode: "form" }
# !uv pip install --system -q git+https://github.com/ralf-42/GenAI.git#subdirectory=04_modul
from genai_lib.utilities import (
    check_environment,
    get_ipinfo,
    setup_api_keys,
    mprint,
    install_packages,
    mermaid,
    get_model_profile,
    extract_thinking,
    load_prompt
)

print()
check_environment()
print()
get_ipinfo()

# %% [markdown]
# # 1 | Kursbeschreibung
# ---

# %% [markdown]
# Dieser Kurs richtet sich an Einsteiger, die das Potenzial von Generativer Künstlicher Intelligenz (GenAI) in praktischen Anwendungen erschließen möchten. Eingesetzt werden moderne KI-Tools wie ChatGPT, LangChain und Hugging Face — von den Grundlagen bis zu fortgeschrittenen Anwendungen.
#
# Der Kurs deckt folgende Bereiche ab: den effektiven Einsatz existierender KI-Modelle, die Verarbeitung von Texten, Bildern und Sprache mit KI, die Entwicklung eigener Chat-Anwendungen, die Anpassung von KI-Modellen an spezifische Anforderungen sowie die intelligente Verarbeitung von Dokumenten und Daten.
#
# Der **Fokus** liegt auf der praktischen Implementierung mit Python und etablierten Frameworks. Theoretische Konzepte werden nur so weit vermittelt, wie sie für Verständnis und Anwendung notwendig sind.

# %% [markdown]
# <p><font color='darkblue' size="4">
# 🎯 <b>Zielgruppe</b>
# </font></p>
#
# Angesprochen sind **Programmierende und Entwickelnde**, die erste Schritte im Bereich der Generativen KI unternehmen wollen, sowie **IT-Fachkräfte**, die KI-Technologien in bestehende Projekte integrieren möchten. Quereinsteiger:innen sind willkommen, sofern **gute Grundkenntnisse in Python und Programmiererfahrung** vorhanden sind.
#
# <br>
#
# <p><font color='darkblue' size="4">
# ✏️ <b>Voraussetzungen</b>
# </font></p>
#
# Erwartet werden **gute Grundlagenkenntnisse** in Python: Datentypen, Listen, Tuple, Dictionary, Kontrollstrukturen, Funktionen und Bibliotheken. Der Kurs ist kein Selbstläufer — er erfordert volle Aufmerksamkeit und aktive Mitarbeit. Die Inhalte werden Schritt für Schritt erarbeitet.
#
# <br>
#
# <p><font color='darkblue' size="4">
# ✏️ <b>Kursergebnis</b>
# </font></p>
#
# Nach Abschluss des Kurses lassen sich GenAI-Technologien in eigenen Projekten einsetzen und moderne KI-Tools für praktische Aufgabenstellungen nutzen.

# %% [markdown]
# <p><font color='darkblue' size="4">
# 📢 <b>Was ist sonst noch wichtig</b>
# </font></p>
#
# Als Entwicklungsumgebung kommt Colaboratory (kurz: Colab) von Google zusammen mit Google Drive zum Einsatz — dafür ist ein **Google-Account** erforderlich (kostenlos). Google Colab muss vorab im Google-Konto aktiviert werden: dazu die Google Workspace Marketplace-Seite für Colab aufrufen und auf "Installieren" klicken. Ist Colab bereits aktiviert, erscheint stattdessen "Deinstallieren" — dann ist kein weiterer Schritt nötig.
#
# Zur Bearbeitung der Aufgaben **kann und soll** auch generative KI (z. B. ChatGPT, Claude oder Gemini) eingesetzt werden. Der gezielte und reflektierte Einsatz solcher Werkzeuge ist Teil des Lernprozesses.
#
# <p><font color='darkblue' size="4">
# 📑 <b>Benötigte Accounts & Zugänge</b>
# </font></p>
#
# + einen OpenAI-Account (kostenlos),
# + OpenAI-API-Key (für die Bearbeitung der Aufgaben ist der Kauf von OpenAI-API-Guthaben im Wert von 5-10 Euro erforderlich). **Bitte Account, API-Key und Guthaben vor Kursbeginn anlegen.**
# + Hugging Face Account und Hugging-Face-API-Key (beides kostenlos). **Bitte Account und API-Key vor Kursbeginn anlegen.**
#
# + Im Kurs wird die Plattform taskcards.de als digitale Pinnwand genutzt.
#
# + Das Lehrmaterial ist kostenlos als PDF bzw. Jupyter-Notebook verfügbar und wird über ein GitHub-Repository bereitgestellt.
#
# + Bei Verwendung eines Business-Laptops empfiehlt sich vorab die Prüfung, ob die gewünschten Anwendungen und Funktionen gemäß den IT-Richtlinien des Unternehmens zulässig bzw. freigeschaltet sind.

# %% [markdown]
# # 2 | Kursmodule
# ---

# %% [markdown]
# **Interaktive Orientierung**
#
# - [Modellauswahl](https://editor.p5js.org/ralf.bendig.rb/full/8BbTi8Ico)

# %% [markdown]
# Die Module sind in sieben thematische Blöcke gegliedert:
#
# - **Grundlagen (Module 1–2)**: Einführung in Generative KI und LangChain-Einstieg
# - **Framework & Patterns (Module 3–5)**: Transformer-Theorie, Structured Output und Memory
# - **RAG (Module 6–7)**: Retrieval Augmented Generation mit Dokumenten und Datenbanken
# - **Agenten & Orchestrierung (Module 8–10)**: GenAI-Apps, Middleware und Model Context Protocol
# - **Deployment & Optimierung (Module 11–13)**: Gradio, lokale Modelle und Fine-Tuning
# - **Multimodal (Module 14–17)**: Bild, multimodales RAG, Audio und Video
# - **Basics – Optional (Module 19–20)**: Modellsteuerung und Codierung mit KI

# %%
#@markdown   <p><font size="4" color='green'>  Kursprogression</font> </br></p>

diagram = """
# %%{init: {
  'theme': 'base',
  'themeVariables': {
    'timelineLineColor': '#2e7d32',
    'sectionBkgColor': '#c8e6c9',
    'sectionTextColor': '#1b5e20',
    'containerBkgColor': '#f9f9f9',
    'taskBkgColor': '#e8f5e9',
    'taskTextColor': '#1b5e20'
  }
}}%%
timeline
    title GenAI-Progression im Kursverlauf
    section Grundlagen
        Erste GenAI-Anwendung : Prompting, Chains, erste Workflows
                              : M01-M02
    section Strukturierte Ausgaben
        Robuste Workflows     : Parser, Memory, Ausgabesteuerung
                              : M03-M05
    section Wissensbasierte GenAI
        RAG und SQL-RAG       : Retrieval, Datenbanken, Fragen beantworten
                              : M06-M07
    section Handlungsfähige GenAI
        Agenten und UI        : Tools, Middleware, MCP, Gradio
                              : M08-M11
    section Erweiterte GenAI
        Lokal und Multimodal  : Ollama, Bild, Audio, Video
                              : M12-M17
"""

mermaid(diagram, width=1200)

# %% [markdown]
# <p><font color='darkblue' size="4">
# ✨ <b>Modul-Übersicht</b>
# </font></p>

# %% [markdown]
# | Modul | Block | Inhalt | Themen | Relevanz |
# | :---: | ----- | ------ | ------ | :------: |
# | 1 | Grundlagen | Einführung GenAI | • Kursüberblick<br>• Überblick Generative AI<br>• Einführung OpenAI<br>• Einführung Hugging Face<br>• Einführung LangChain | Fundamentales Verständnis der Gen-AI-Technologien<br>als Grundlage für den Kurs. |
# | 2 | Framework & Patterns | LangChain 101 | • Was ist LangChain & Architektur<br>• Kernkonzepte (Chains, Models, Prompts, Graph)<br>• Best Practices & Design Patterns | Fundamentales Verständnis von LangChain/LangGraph<br>als zentrales Framework für LLM-Anwendungen. |
# | 3 | Framework & Patterns | Large Language Model | • Foundation Model<br>• Transformer-Architektur<br>• Textgenerierung<br>• Textzusammenfassung<br>• Textklassifizierung<br>• LLM schreibt ein Buch | Vertieftes Verständnis der Transformer-Architektur<br>und LLM-Funktionsweise. |
# | 4 | Framework & Patterns | Structured Output | • Structured Output Parser<br>• JSON<br>• DatetimeOutputParser<br>• Structured Output | Parser-Typen für robuste und flexible Verarbeitung<br>von Modellantworten. |
# | 5 | Framework & Patterns | Chat und Memory | • Übersicht<br>• Kurzzeit-Memory<br>• persistentes Memory<br>• Externes Memory | Memory-Typen für Flexibilität und Skalierbarkeit,<br>um Konversationen effizient zu verwalten. |
# | 6 | RAG | Retrieval Augmented Generation | • Einführung in RAG<br>• ChromaDB<br>• Embeddings<br>• Q&A über Dokumente<br>• Embedding-Datenbanken | Schlüsseltechnologie für Informationsverarbeitung<br>mit unstrukturierten Daten. |
# | 7 | RAG | SQL RAG | • Einführung in SQL RAG<br>• Vergleich zu RAG<br>• Integration von LLMs mit Datenbanken<br>• SQL-Generierung mit LLMs<br>• SQL RAG mit LangChain | Schlüsseltechnologie für die Arbeit mit<br>strukturierten Daten und Datenbanken. |
# | 8 | Agenten & Orchestrierung | Agenten | • Grundlagen von GenAI-Apps<br>• Agentenarchitekturen<br>• Planung und Zielverfolgung<br>• Multi-Agentensysteme | Entwicklung autonomer KI-Systeme. |
# | 9 | Agenten & Orchestrierung | Middleware | • Middleware-Konzepte<br>• Decorator-Hooks (before/after/wrap)<br>• Human-in-the-Loop<br>• Summarization, Retry<br>• Middleware kombinieren | Kontrolle und Steuerung von Agent-Ausführungen<br>durch konfigurierbare Zwischenschichten. |
# | 10 | Agenten & Orchestrierung | MCP – Model Context Protocol | • Intro<br>• MCP-Server erstellen<br>• MCP-Client erstellen<br>• AI-Assistant mit MCP<br>• MCP in der Praxis | Standardisiertes Protokoll für<br>LLM-Tool-Integration. |
# | 11 | Deployment & Optimierung | Gradio | • Grundkonzepte von Gradio<br>• Zentrale Komponenten<br>• Praktische Beispiele<br>• Integration mit KI-Modellen<br>• Best Practices<br>• Deployment und Sharing | UI-Entwicklung für KI-Anwendungen. |
# | 12 | Deployment & Optimierung | Lokale und Open Source Modelle | • Einführung<br>• Ollama<br>• Lokale Modelle und LangChain<br>• Open Source vs. Closed Source<br>• Lizenzierung und rechtliche Aspekte<br>• Auswahlkriterien | Einsatz von KI-Modellen ohne Cloud-Abhängigkeit. |
# | 13 | Deployment & Optimierung | Fine-Tuning | • Fine-Tuning mit Dashboard<br>• Fine-Tuning mit Code<br>• Parameter Efficient Fine-Tuning<br>• Bewerten des FT-Modells | Optimierung und effiziente Anpassung für<br>spezifische Anwendungsfälle. |
# | 14 | Multimodal | Multimodal Bild | • Bildgenerierung<br>• In-/Outpainting<br>• Bildklassifizierung<br>• Objekterkennung<br>• Bildbeschreibung | Erweiterung um visuelle Komponenten. |
# | 15 | Multimodal | Multimodal RAG | • Enhanced Document Processor<br>• Multimodal Embeddings<br>• Cross-Modale Suche | Schlüsseltechnologie für die Arbeit mit<br>Texten und Bildern. |
# | 16 | Multimodal | Multimodal Audio | • Speech-to-Text (STT)<br>• Text-to-Speech (TTS)<br>• Sprachanalyse<br>• Audio-Summary<br>• Audio-Pipeline<br>• Podcast | Erschließung von Sprachanwendungen. |
# | 17 | Multimodal | Multimodal Video | • Video-zu-Text (VTT)<br>• Text-zu-Video (TTV)<br>• Bild-zu-Video (ITV)<br>• Videoanalyse<br>• Video-Objekterkennung | Integration von Videoverarbeitung und -analyse<br>für multimodale KI-Anwendungen. |
# | 19 | Basics – optional | Modellsteuerung | • Prompting-Strategien<br>• Modellparameter (Temperature, Top-P)<br>• Context Engineering<br>• Modellverhalten gezielt steuern | Vertiefung der LLM-Steuerung<br>für präzisere und kontrollierte Ausgaben. |
# | 20 | Basics – optional | Codieren mit GenAI | • Prompting für Codegenerierung<br>• Revisionsprompts<br>• Debugging mit LLMs<br>• Prozessintegration<br>• Claude Code | Praktische Fähigkeiten für LLM-gestützte<br>Programm-Entwicklung. |

# %% [markdown]
# # 3 | Kurs-Guide
# ---

# %% [markdown]
# <p><font color='darkblue' size="4">
# 🚀 <b>Erfolgsfaktoren für den Kurs</b>
# </font></p>
#
# Der Lernerfolg stellt sich vor allem durch **aktives Mitmachen** ein: theoretische Beispiele werden direkt nachvollzogen, Unklarheiten sofort angesprochen und eigene Anwendungsfälle in die Gruppe eingebracht. Gelehrt wird durch direktes Experimentieren — konkrete Arbeitsaufgaben lassen sich jederzeit einbringen und gemeinsam mit KI-Tools lösen.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ralf-42/GenAI/main/07_image/kompetenzillusion.png" class="logo" width="900"/>
# <p><font color='black' size="2">
# KI-generiertes Bild
# </font></p>

# %% [markdown]
# <p><font color='darkblue' size="4">
# ✅ <b>Kursziele</b>
# </font></p>
#
# Am Ende des Kurses sind folgende Kompetenzen aufgebaut:
# - KI-Tools effektiv in den Arbeitsalltag integrieren
# - Hochwertige Prompts erstellen
# - Das Potenzial verschiedener KI-Modelle einschätzen
# - Praktische Anwendungsfälle selbstständig umsetzen
#
# **Erfolgsmessung:** Praktische Anwendung der gelernten Techniken auf eigene Arbeitsaufgaben

# %% [markdown]
# <p><font color='darkblue' size="4">
# 📌 <b>Wichtig</b>
# </font></p>
#
# Die Aufgabestellungen in den Modulen bieten Anregungen — es ist aber auch möglich, eine andere Herausforderung anzugehen.
#
# **Hinweis zur Lösungshilfe:**
# > In diesem Kurs **darf** und **soll** generative KI auch als Unterstützung beim Lernen und Entwickeln eingesetzt werden. Bei einer festgefahrenen Aufgabe lässt sich z. B. Gemini in Google Colab nutzen, um Fehlermeldungen besser zu verstehen, Ideen für Teilschritte zu erhalten oder Code-Varianten zu prüfen.
# > <br>**Wichtig ist nur:** Die KI dient als Lern- und Entwicklungshilfe. Der Schwerpunkt des Kurses bleibt darauf, generative KI selbst zu verstehen, aufzubauen und gezielt weiterzuentwickeln.

# %% [markdown]
# # 4 | Accounts & API-Keys
# ---

# %% [markdown]
# + **Google:** Für die Arbeit mit Google Colab und Google Drive ist ein Google-Account erforderlich (kostenlos).
# + **OpenAI:** Für den Zugriff auf die OpenAI-API wird ein Account mit hinterlegter Zahlungsart benötigt. Für den Abschluss des Kurses sind erfahrungsgemäß etwa 5–10 EUR einzuplanen.
# + **Hugging Face:** Zum Download bestimmter vortrainierter Modelle ist ein HuggingFace-Account mit API-Key erforderlich (kostenlos).

# %% [markdown]
# - [OpenAI](https://platform.openai.com/settings/organization/general)
# - [Hugging Face](https://huggingface.co/)

# %% [markdown]
# # A | Dokumente zum Weiterlesen
# ---

# %% [markdown]
# 📚 Ergänzende Artikel aus der Kurs-Dokumentation:
#
# - [Aufgabenklassen & Loesungswege](https://ralf-42.github.io/GenAI/02-orientierung/aufgabenklassen-und-loesungswege.html)
# - [KI-Reifegradmodell](https://ralf-42.github.io/GenAI/02-orientierung/ki-reifegradmodell.html)
# - [Lohnt sich GenAI?](https://ralf-42.github.io/GenAI/02-orientierung/lohnt-es-sich.html)
