# %% [markdown]
# <p><font size="6" color='grey'> <b>
#
# Generative KI. Verstehen. Anwenden. Gestalten.
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# Kurs Intro
# </b></font> </br></p>
#
# ---

# %% [markdown]
# # 1 | Kursbeschreibung
# ---

# %% [markdown]
# Dieser Kurs richtet sich an **Einsteiger**, die das Potenzial von Generativer Künstlicher Intelligenz (GenAI) in **praktischen Anwendungen** erschließen möchten. Sie lernen, wie Sie moderne KI-Technologien wie ChatGPT, LangChain und Hugging Face für Ihre eigenen Projekte nutzen können.
#
# In praxisorientierten Modulen geht es von den Grundlagen bis hin zu fortgeschrittenen Anwendungen. Sie lernen, wie Sie:
#
# + **existierende** KI-Modelle effektiv einsetzen,
# + Texte, Bilder und Sprache mit KI verarbeiten,
# + eigene Chat-Anwendungen entwickeln,
# + KI-Modelle an Ihre spezifischen Anforderungen anpassen,
# + Dokumente und Daten intelligent verarbeiten.
#
# Der **Fokus** liegt dabei durchgehend auf der praktischen Implementierung: Sie arbeiten mit Python und nutzen etablierte Frameworks und Tools. Theoretische Konzepte werden nur soweit vermittelt, wie sie für das Verständnis und die Anwendung notwendig sind.

# %% [markdown]
# <p><font color='darkblue' size="4">
# 🎯 <b>Zielgruppe</b>
# </font></p>
#
#
#
# + **Programmierende** und **Entwickelnde**, die ihre ersten Schritte im Bereich der Generativen Künstlichen Intelligenz (GenAI) unternehmen möchten,
#
# + **IT-Fachkräfte**, die daran interessiert sind, KI-Technologien in bestehende Projekte zu integrieren,
#
# + technikbegeisterte Quereinsteiger:innen **mit guten Grundkenntnissen in Python und Programmiererfahrung**.
#
# <br>
#
# <p><font color='darkblue' size="4">
# ✏️ <b>Was bringen Sie mit?</b>
# </font></p>
#
# + Sie haben **gute Grundlagenkenntnisse** in Python (Datentypen, Listen, Tuple, Dictionary, Kontrollstrukturen, Funktionen, Bibliotheken).
#
# + Dieser Kurs ist kein Selbstläufer - er erfordert Ihre volle Aufmerksamkeit und aktive Mitarbeit. Gemeinsam erarbeiten wir die Inhalte Schritt für Schritt, damit Sie am Ende sicher im Thema stehen.
#
# <br>
#
# <p><font color='darkblue' size="4">
# ✏️ <b>Was nehmen Sie mit?</b>
# </font></p>
#
#
#
# Nach Abschluss des Kurses sind Sie in der Lage, GenAI-Technologien in Ihren eigenen Projekten einzusetzen und moderne KI-Tools für praktische Aufgabenstellungen zu nutzen

# %% [markdown]
# <p><font color='darkblue' size="4">
# 📢 <b>Was ist sonst noch wichtig</b>
# </font></p>
#
#
# + Wir arbeiten mit der Entwicklungsumgebung Colaboratory (kurz: Colab) von Google und Google Drive, hierfür benötigen Sie einen **Google-Account** (kostenlos).
#
# + Google Colab muss vorab in Ihrem Google-Konto aktiviert werden. Rufen Sie die Google Workspace Marketplace-Seite für Colab auf und klicken Sie auf die Schaltfläche "Installieren". Folgen Sie den Anweisungen und Hinweisen. Wenn Colab bereits aktiviert ist, wird auf der Schaltfläche stattdessen "Deinstallieren" angezeigt. In diesem Fall müssen Sie nichts weiter tun.
#
# + Zur Bearbeitung der Aufgaben **kann und soll** auch generative KI (z. B. ChatGPT, Claude oder Gemini) eingesetzt werden. Der gezielte und reflektierte Einsatz solcher Werkzeuge ist Teil des Lernprozesses.
#
# <p><font color='darkblue' size="4">
# 📑 <b>Sie brauchen zudem</b>
# </font></p>
#
#
# +  einen OpenAI-Account (kostenlos),
# + OpenAI-API-Key (für die Bearbeitung der Aufgaben ist der Kauf von OpenAI-API-Guthaben im Wert von 5-10 Euro erforderlich). **Bitte Account, API-Key und Guthaben vor Kursbeginn anlegen.**
# + Hugging Face Account und Hugging-Face-API-Key (beides kostenlos). **Bitte Account und API-Key vor Kursbeginn anlegen.**
#
# + Im Kurs nutzen wir die Plattform taskcards.de als digitale Pinnwand.
#
# + Das Lehrmaterial ist kostenlos als PDF bzw. Jupyter-Notebook verfügbar und wird über ein GitHub-Repository bereitgestellt.
#
# + Bei Verwendung eines Business-Laptops vergewissern Sie sich bitte, dass die gewünschten Anwendungen und Funktionen gemäß den IT-Richtlinien des Unternehmens zulässig bzw. freigeschaltet sind.

# %% [markdown]
# # 2 | Kursmodule
# ---

# %% [markdown]
# Die Module sind in sieben thematische Blöcke gegliedert:
#
# - **Grundlagen (Module 1–3)**: Einführung in Generative KI, Modellsteuerung und Codierung mit KI
# - **Framework & Patterns (Module 4–7)**: LangChain, Transformer-Theorie, Structured Output und Memory
# - **RAG (Module 8–9)**: Retrieval Augmented Generation mit Dokumenten und Datenbanken
# - **Agenten & Orchestrierung (Module 10–12)**: GenAI-Apps, Middleware und Model Context Protocol
# - **Deployment & Optimierung (Module 13–15)**: Gradio, lokale Modelle und Fine-Tuning
# - **Multimodal (Module 16–19)**: Bild, multimodales RAG, Audio und Video
# - **No-Code / Low-Code (Modul 20)**: OpenAI Agent Builder

# %%
#@markdown   <p><font size="4" color='green'>  Kursprogression</font> </br></p>

diagram = """
# %%{init: {
  'theme': 'base',
  'themeVariables': {
    'timelineLineColor': '#2e7d32',
    'sectionBkgColor': '#c8e6c9',
    'sectionTextColor': '#1b5e20',
    'containerBkgColor': '#f9f9f9',
    'taskBkgColor': '#e8f5e9',
    'taskTextColor': '#1b5e20'
  }
}}%%
timeline
    title GenAI-Progression im Kursverlauf
    section Grundlagen
        Erste GenAI-Anwendung : Prompting, Chains, erste Workflows
                              : M01-M04
    section Strukturierte Ausgaben
        Robuste Workflows     : Parser, Memory, Ausgabesteuerung
                              : M05-M07
    section Wissensbasierte GenAI
        RAG und SQL-RAG       : Retrieval, Datenbanken, Fragen beantworten
                              : M08-M09
    section Handlungsfaehige GenAI
        Agenten und UI        : Tools, Middleware, MCP, Gradio
                              : M10-M13
    section Erweiterte GenAI
        Lokal und Multimodal  : Ollama, Bild, Audio, Video
                              : M14-M19
"""

mermaid(diagram, width=1200)

# %% [markdown]
# <p><font color='darkblue' size="4">
# ✨ <b>Modul-Übersicht</b>
# </font></p>

# %% [markdown]
# | Modul | Block | Inhalt | Themen | Relevanz |
# | :---: | ----- | ------ | ------ | :------: |
# | 1 | Grundlagen | Einführung GenAI | • Kursüberblick<br>• Überblick Generative AI<br>• Einführung OpenAI<br>• Einführung Hugging Face<br>• Einführung LangChain | Fundamentales Verständnis der Gen-AI-Technologien<br>als Grundlage für den Kurs. |
# | 2 | Grundlagen | Modellsteuerung | • Überblick Prompting, Context Engineering, RAG, Fine-Tuning<br>• Einsatzszenarien<br>• Entscheidungskriterien<br>• Trade-offs | Essentielles Verständnis der verschiedenen Ansätze<br>zur Modellansteuerung. |
# | 3 | Grundlagen | Codieren mit GenAI | • Prompting für Codegenerierung<br>• Revisionsprompts<br>• Debugging mit LLMs<br>• Prozessintegration<br>• Claude Code | Praktische Fähigkeiten für LLM-gestützte<br>Programm-Entwicklung. |
# | 4 | Framework & Patterns | LangChain 101 | • Was ist LangChain & Architektur<br>• Kernkonzepte (Chains, Models, Prompts, Graph)<br>• Best Practices & Design Patterns | Fundamentales Verständnis von LangChain/LangGraph<br>als zentrales Framework für LLM-Anwendungen. |
# | 5 | Framework & Patterns | Large Language Models und Transformer | • Foundation Model<br>• Transformer-Architektur<br>• Textgenerierung<br>• Textzusammenfassung<br>• Textklassifizierung<br>• LLM schreibt ein Buch | Vertieftes Verständnis der Transformer-Architektur<br>und LLM-Funktionsweise. |
# | 6 | Framework & Patterns | Structured Output | • Structured Output Parser<br>• JSON<br>• DatetimeOutputParser<br>• Structured Output | Parser-Typen für robuste und flexible Verarbeitung<br>von Modellantworten. |
# | 7 | Framework & Patterns | Chat und Memory | • Übersicht<br>• Kurzzeit-Memory<br>• Langzeit-Memory<br>• Externes Memory | Memory-Typen für Flexibilität und Skalierbarkeit,<br>um Konversationen effizient zu verwalten. |
# | 8 | RAG | Retrieval Augmented Generation | • Einführung in RAG<br>• ChromaDB<br>• Embeddings<br>• Q&A über Dokumente<br>• Embedding-Datenbanken | Schlüsseltechnologie für Informationsverarbeitung<br>mit unstrukturierten Daten. |
# | 9 | RAG | SQL RAG | • Einführung in SQL RAG<br>• Vergleich zu RAG<br>• Integration von LLMs mit Datenbanken<br>• SQL-Generierung mit LLMs<br>• SQL RAG mit LangChain | Schlüsseltechnologie für die Arbeit mit<br>strukturierten Daten und Datenbanken. |
# | 10 | Agenten & Orchestrierung | Agenten | • Grundlagen von GenAI-Apps<br>• Agentenarchitekturen<br>• Planung und Zielverfolgung<br>• Multi-Agentensysteme | Entwicklung autonomer KI-Systeme. |
# | 11 | Agenten & Orchestrierung | Middleware | • Middleware-Konzepte<br>• Decorator-Hooks (before/after/wrap)<br>• Human-in-the-Loop<br>• Summarization, Retry<br>• Middleware kombinieren | Kontrolle und Steuerung von Agent-Ausführungen<br>durch konfigurierbare Zwischenschichten. |
# | 12 | Agenten & Orchestrierung | MCP – Model Context Protocol | • Intro<br>• MCP-Server erstellen<br>• MCP-Client erstellen<br>• AI-Assistant mit MCP<br>• MCP in der Praxis | Standardisiertes Protokoll für<br>LLM-Tool-Integration. |
# | 13 | Deployment & Optimierung | Gradio | • Grundkonzepte von Gradio<br>• Zentrale Komponenten<br>• Praktische Beispiele<br>• Integration mit KI-Modellen<br>• Best Practices<br>• Deployment und Sharing | UI-Entwicklung für KI-Anwendungen. |
# | 14 | Deployment & Optimierung | Lokale und Open Source Modelle | • Einführung<br>• Ollama<br>• Lokale Modelle und LangChain<br>• Open Source vs. Closed Source<br>• Lizenzierung und rechtliche Aspekte<br>• Auswahlkriterien | Einsatz von KI-Modellen ohne Cloud-Abhängigkeit. |
# | 15 | Deployment & Optimierung | Fine-Tuning | • Fine-Tuning mit Dashboard<br>• Fine-Tuning mit Code<br>• Parameter Efficient Fine-Tuning<br>• Bewerten des FT-Modells | Optimierung und effiziente Anpassung für<br>spezifische Anwendungsfälle. |
# | 16 | Multimodal | Multimodal Bild | • Bildgenerierung<br>• In-/Outpainting<br>• Bildklassifizierung<br>• Objekterkennung<br>• Bildbeschreibung | Erweiterung um visuelle Komponenten. |
# | 17 | Multimodal | Multimodal RAG | • Enhanced Document Processor<br>• Multimodal Embeddings<br>• Cross-Modale Suche | Schlüsseltechnologie für die Arbeit mit<br>Texten und Bildern. |
# | 18 | Multimodal | Multimodal Audio | • Speech-to-Text (STT)<br>• Text-to-Speech (TTS)<br>• Sprachanalyse<br>• Audio-Summary<br>• Audio-Pipeline<br>• Podcast | Erschließung von Sprachanwendungen. |
# | 19 | Multimodal | Multimodal Video | • Video-zu-Text (VTT)<br>• Text-zu-Video (TTV)<br>• Bild-zu-Video (ITV)<br>• Videoanalyse<br>• Video-Objekterkennung | Integration von Videoverarbeitung und -analyse<br>für multimodale KI-Anwendungen. |
# | 20 | No-Code / Low-Code | OpenAI Agent Builder | • Überblick Agent Builder Plattform<br>• Agenten visuell erstellen und konfigurieren<br>• Tools und Funktionen einbinden<br>• Knowledge-Dateien und Instruktionen<br>• Testen, Iterieren und Veröffentlichen<br>• Vergleich: Agent Builder vs. Code-basierte Agenten | Agenten ohne Programmierung erstellen –<br>Brücke zwischen No-Code und professioneller Entwicklung. |

# %% [markdown]
# # 3 | Kurs-Guide
# ---

# %% [markdown]
# <p><font color='darkblue' size="4">
# 🚀 <b>Erfolgsfaktoren für den Kurs</b>
# </font></p>
#
#
# **Aktive Teilnahme**
# - **Praktisches Ausprobieren** während der Demonstrationen
# - **Fragen stellen** bei Unklarheiten
# - **Eigene Anwendungsfälle** mit der Gruppe teilen
#
# **Praxisorientiertes Lernen**
# - Lernen durch direktes Experimentieren
# - Bringen Sie konkrete Arbeitsaufgaben mit
# - Gemeinsame Problemlösung mit KI-Tools

# %% [markdown]
# <p><font color='darkblue' size="4">
# ✅ <b>Kursziele</b>
# </font></p>
#
#
# Am Ende des Kurses können Sie:
# - KI-Tools effektiv in Ihren Arbeitsalltag integrieren
# - Hochwertige Prompts erstellen
# - Das Potenzial verschiedener KI-Modelle einschätzen
# - Praktische Anwendungsfälle selbstständig umsetzen
#
# **Erfolgsmessung:** Praktische Anwendung der gelernten Techniken auf eigene Arbeitsaufgaben

# %% [markdown]
# <p><font color='darkblue' size="4">
# 📌 <b>Wichtig</b>
# </font></p>
#
# Die Aufgabestellungen in den Modulen bieten Anregungen, Sie können aber auch gerne eine andere Herausforderung angehen.
#
# **Hinweis zur Lösungshilfe:**
# > In diesem Kurs dürfen und sollen Sie generative KI auch als Unterstützung beim Lernen und Entwickeln nutzen. Wenn Sie bei einer Aufgabe festhängen, können Sie zum Beispiel Gemini in Google Colab verwenden, um Fehlermeldungen besser zu verstehen, Ideen für Teilschritte zu bekommen oder Code-Varianten zu prüfen.
# > <br>**Wichtig ist nur:** Die KI dient als Lern- und Entwicklungshilfe. Der Schwerpunkt des Kurses bleibt darauf, KI-Agenten selbst zu verstehen, aufzubauen und gezielt weiterzuentwickeln.

# %% [markdown]
# # 4 | Accounts & API-Keys
# ---

# %% [markdown]
# + **Google:** Sie müssen sich bei Google anmelden und einen kostenlosen Google-Account erhalten, um mit Google Colab und Google Drive zu arbeiten.
# + **OpenAI:** Sie müssen sich bei OpenAI anmelden und einen OpenAI-Schlüssel erwerben und mit einer Zahlungsart verknüpfen. Rechnen Sie damit, für den Abschluss dieses Kurses etwa 5-10 EUR auszugeben.
# + **Hugging Face:** Sie müssen sich bei HuggingFace anmelden und einen kostenlosen Schlüssel erhalten, um bestimmte vortrainierte Modelle herunterzuladen.

# %% [markdown]
# [OpenAI](https://platform.openai.com/settings/organization/general)
# [Hugging Face](https://huggingface.co/)
