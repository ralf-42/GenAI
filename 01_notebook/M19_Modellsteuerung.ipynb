# %% [markdown]
# <p><font size="6" color='grey'> <b>
#
# Generative KI. Verstehen. Anwenden. Gestalten.
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# Modellsteuerung
# </b></font> </br></p>
#
# ---

# %% [markdown]
# <p><font color='darkblue' size="4">
# ℹ️ <b>Information</b>
# </font></p>
#
# > Dieses Notebook nutzt **direkte OpenAI-API** (`openai.chat.completions`) ohne LangChain, um die Grundlagen der Modellsteuerung (Temperatur, Tokens, Stop-Sequenzen) ohne Framework-Abstraktion zu zeigen.

# %%
#@title 🔧 Umgebung einrichten{ display-mode: "form" }
# !uv pip install --system -q git+https://github.com/ralf-42/GenAI.git#subdirectory=04_modul

# ── Projekt-Utilities ─────────────────────────────────────────────────────────
from genai_lib.utilities import (
    check_environment,
    get_ipinfo,
    setup_api_keys,
    mprint,
    install_packages,
    mermaid,
    get_model_profile,
    extract_thinking,
    load_prompt
)
setup_api_keys(['OPENAI_API_KEY'], create_globals=False)
print()
check_environment()
print()
get_ipinfo()

# %% [markdown]
# # 1 | Modellsteuerung
# ---

# %% [markdown]
# <p><font color='darkblue' size="4">
# 💡 <b>Viz</b>
# </font></p>
#
#
# - [Modellsteuerung](https://editor.p5js.org/ralf.bendig.rb/full/um423ggnD)
# - [Entscheidungshilfe Modellsteuerung](https://editor.p5js.org/ralf.bendig.rb/full/xb3zPgRSr)
# - [LLM-Parameter](https://editor.p5js.org/ralf.bendig.rb/full/LBc3t3yP4)
# - [Modellauswahl](https://editor.p5js.org/ralf.bendig.rb/full/8BbTi8Ico)

# %% [markdown]
# Die Qualität eines KI-Systems hängt nicht allein vom zugrunde liegenden Sprachmodell ab, sondern maßgeblich davon, wie dieses Modell gesteuert, eingegrenzt und mit Kontext versorgt wird. Moderne KI-Anwendungen bestehen daher nicht nur aus einem einzelnen Modell, sondern aus einer Kombination verschiedener Steuerungsmechanismen, die Präzision, Nachvollziehbarkeit und Verlässlichkeit verbessern sollen.
#
# Zur Modellsteuerung gehören insbesondere System-Prompts, Kontext-Injektion (Retrieval-Augmented Generation), Fine-Tuning sowie orchestrierende Komponenten, die Aufgaben strukturieren und kontrollieren. Während der System-Prompt grundlegende Regeln, Rollen und den gewünschten Antwortstil definiert, liefert die Kontext-Injektion aktuelle und relevante juristische Quellen wie Gesetze, Urteile oder Kommentare. Fine-Tuning kann zusätzlich eingesetzt werden, um ein Modell auf spezifische Fachgebiete oder Arbeitsweisen zu spezialisieren.
#
# Darüber hinaus übernehmen Orchestrierungs- und Kontrollmechanismen wichtige Aufgaben wie die Zerlegung komplexer Anfragen, die Auswahl geeigneter Werkzeuge, Qualitätsprüfungen oder Halluzinationsfilter. Erst das Zusammenspiel dieser Komponenten ermöglicht es, aus einem allgemeinen Sprachmodell ein z.B. ein *spezialisiertes juristisches KI-System* zu entwickeln, das im professionellen Arbeitsalltag sinnvoll eingesetzt werden kann.

# %% [markdown]
# <p><font color='black' size="5">
# Beispiel: Juristisches KI-System
# </font></p>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ralf-42/GenAI/main/07_image/legal_system.png" class="logo" width="850"/>
# <p><font color='black' size="2">
# KI-generiertes Bild
# </font></p>

# %% [markdown]
# Die nachfolgende Tabelle liefert eine Übersicht über Verfahren, die zur Modellsteuerung und -optimierung eingesetzt werden können.

# %% [markdown]
# | Nr. | Methode | Technischer Aufwand | Typische Anwendung | Erläuterung |
# | :-- | :--- | :--- | :--- | :--- |
# | 1 | Prompt Engineering | sehr gering | Basis für alle LLM-Anwendungen | Systematische Gestaltung von Eingabetexten zur Optimierung der Modellausgaben. |
# | 2 | Few-Shot Learning | sehr gering | Schnelle Aufgabenanpassung | Bereitstellung weniger Beispiele im Prompt, damit das Modell neue Aufgaben ohne Training lernt. |
# | 3 | RAG (Retrieval-Augmented Gen.) | mittel | Wissensbasierte Anwendungen | Kombination von Informationsabruf aus externen Datenquellen mit Textgenerierung. |
# | 4 | Chain-of-Thought Prompting | sehr gering | Komplexe Reasoning-Aufgaben | Anleitung des Modells, Denkschritte explizit zu formulieren für bessere Problemlösung. |
# | 5 | API Parameter Tuning | sehr gering | Optimierung von Output-Qualität | Anpassung von Temperature, Top-p, Max-Tokens etc. zur Steuerung der Ausgabecharakteristik. |
# | 6 | Function Calling / Tool Use | gering | Integration ext. Services/Daten | Ermöglicht dem Modell, strukturierte externe Funktionen und APIs aufzurufen. |
# | 7 | Adapter-Tuning / LoRA | mittel – hoch | Effiziente Modellanpassung | Trainiert nur kleine Adapterschichten statt des gesamten Modells für spezifische Aufgaben. |
# | 8 | LangChain / LCEL Pipelines | mittel | Komplexe LLM-Anwendungsarchitekturen | Framework zur Orchestrierung komplexer LLM-Workflows und -Ketten. |
# | 9 | Self-Consistency Prompting | gering | Verbesserung der Antwortqualität | Mehrfache Ausführung derselben Anfrage und Auswahl der konsistentesten Antwort. |
# | 10 | Context Engineering | gering – mittel | Strukturierung komplexer Inputs | Strategische Anordnung und Strukturierung von Kontextinformationen im Prompt. |
# | 11 | Multimodal Prompting | gering | Text + Bild/Audio/Video Verarbeitung | Verwendung mehrerer Eingabemodaliäten (Text, Bild, Audio) in einem Prompt. |
# | 12 | Fine-Tuning | hoch | Spezialisierung auf Domain/Task | Training des gesamten Modells auf spezifischen Daten für maximale Anpassung. |
# | 13 | Agentic Workflows | mittel – hoch | Autonome, mehrstufige Prozesse | Aufbau autonomer Systeme, die eigenständig Entscheidungen treffen und Aktionen ausführen. |
# | 14 | Instruction Tuning | nicht selbst machbar | Grundlegende Verhaltensanpassung | Training auf Instruktions-Response-Paaren zur Verbesserung der Befolgung von Anweisungen. |
# | 15 | Modell-Ensemble / Routing | mittel – hoch | Spezial-Anwendungen, Redundanz | Kombination mehrerer Modelle oder intelligente Weiterleitung an spezialisierte Modelle. |

# %% [markdown]
# <p><font color='black' size="3">
# <b>Legende</b>
# </font></p>
#
#
# - *Technischer Aufwand*: Implementierungsaufwand und Ressourcenbedarf
# - *Typische Anwendung*: Haupteinsatzgebiete der jeweiligen Methode
# - *Erläuterung*: Kurze Beschreibung der Methode und ihres Zwecks

# %% [markdown]
# - [Modellsteuerung und -optimierung](https://editor.p5js.org/ralf.bendig.rb/full/um423ggnD)

# %% [markdown]
# # 2 | Prompt Engineering
# ---

# %% [markdown]
# Prompting ist die einfachste und direkteste Methode zur Steuerung von LLMs. Dabei wird dem Modell eine Textaufforderung, der sogenannte `Prompt`, gegeben, der die gewünschte Ausgabe beschreibt. Die Qualität der Ausgabe hängt stark von der Qualität des Prompts ab. Ein gut formulierter Prompt sollte klar, prägnant und spezifisch sein.

# %% [markdown]
# - [Say What You See](https://artsandculture.google.com/experiment/say-what-you-see/jwG3m7wQShZngw)

# %% [markdown]
# <p><font color='black' size="5">
# Prompt-Elemente
# </font></p>

# %% [markdown]
# Eingabeaufforderungen bestehen in der Regel aus vier wesentlichen Elementen, die je nach Aufgabe variieren können. Die Hauptbestandteile sind:
#
# * **Anweisungen** – Definieren die Aufgabe des Modells, entweder als Aufgabenbeschreibung oder als konkrete Handlungsanweisung.
# * **Kontext** – Liefert ergänzende Informationen, um das Modell bei der Bearbeitung zu unterstützen.
# * **Eingabedaten** – Enthalten die spezifischen Informationen, zu denen eine Antwort generiert werden soll.
# * **Ausgabeindikator** – Signalisiert den Übergang zur erwarteten Modellantwort.
#
# Weitere Beispiele zur Anwendung dieser Struktur folgen später.

# %% [markdown]
# Nachfolgend ein Beispiel für eine Eingabeaufforderung zur Erstellung einer Produktzusammenfassung.
#
# ```
# Fassen Sie die folgende Produktbewertung in einem Satz zusammen:
# Produkt: Intelligente digitale Personenwaage für Körpergewicht, Fett, BMI, Muskelmassezusammensetzung
# Produktbewertung: Diese Waage ist fantastisch! Der Einrichtungsvorgang war schnell und einfach und
# dauerte nur wenige Minuten. Ich konnte die App kostenlos auf mein etwas veraltetes iPhone 8
# herunterladen. Die Funktion, bei der Ihr Gewicht sofort mit der App synchronisiert wird, macht die
# Nachverfolgung mühelos. Die Funktionen zur Essensplanung und Kalorienzählung der App sind unglaublich
# benutzerfreundlich. Ich bin absolut begeistert! Außerdem hat die Waage ein elegantes, modernes
# Erscheinungsbild, das wirklich attraktiv ist.
#
#
# Zusammenfassung: ...
# ```
#
# Diese Eingabeaufforderung erzeugt möglicherweise die folgende Ausgabe:
#
# ```
# Die intelligente digitale Personenwaage wird für ihre schnelle Einrichtung, die einfache
# Synchronisierung mit ihrer App auf älteren Telefonen zur mühelosen Nachverfolgung, die
# benutzerfreundlichen Funktionen zur Essensplanung und Kalorienzählung sowie ihr schlankes, modernes
# Design hoch gelobt.
# ```

# %% [markdown]
# <p><font color='black' size="5">
# Code-Beispiel
# </font></p>

# %%
# ── OpenAI ────────────────────────────────────────────────────────────────────
from openai import OpenAI, chat

client = OpenAI()

user_input = """
<Task>
Fassen Sie die folgende Produktbewertung in einem Satz zusammen.
</Task>

<Context>
Produkt: Intelligente digitale Personenwaage für Körpergewicht, Fett, BMI, Muskelmassezusammensetzung
Produktbewertung: Diese Waage ist fantastisch! Der Einrichtungsvorgang war schnell und einfach und
dauerte nur wenige Minuten. Ich konnte die App kostenlos auf mein etwas veraltetes iPhone 8
herunterladen. Die Funktion, bei der Ihr Gewicht sofort mit der App synchronisiert wird, macht die
Nachverfolgung mühelos. Die Funktionen zur Essensplanung und Kalorienzählung der App sind unglaublich
benutzerfreundlich. Ich bin absolut begeistert! Außerdem hat die Waage ein elegantes, modernes
Erscheinungsbild, das wirklich attraktiv ist.
</Context>
"""

completion = chat.completions.create(
  model="gpt-5.4-nano",
  messages=[
    {"role": "system", "content": "Du bist ein hilfreicher KI-Assistent."},
    {"role": "user", "content": user_input}
  ]
)

mprint('## 🤖 KI:')
mprint(completion.choices[0].message.content)

# %% [markdown]
# # 3 | Retrieval-Augmented Generation
# ---

# %% [markdown]
# RAG (Retrieval-Augmented Generation) ist eine **hybride Methode**, die die Stärken von **LLMs** mit denen von **Information-Retrieval-Systemen** **kombiniert**. Dabei greift das LLM auf llm-externe Wissensdatenbanken zu, um seine Antworten zu verbessern und die Probleme von Halluzinationen und veralteten Informationen zu mindern.
#
# **Funktionsweise:**
#
# + Der Benutzer gibt eine Anfrage in das RAG-System ein.
# + Das System sucht in externe Wissens nach relevanten Informationen.
# + Die relevanten Informationen werden dem LLM als Kontext bereitgestellt.
# + Das LLM generiert eine Antwort basierend auf der Anfrage **und** dem Kontext.
#
#
# **Einsatzszenarien:**
#
# RAG eignet sich besonders für Aufgaben, die aktuelle oder domänenspezifische Informationen erfordern, wie z. B.:
#
# + Kundensupport mit Zugriff auf Produktdatenbanken
# + Medizinische Diagnose mit Zugriff auf aktuelle Forschungsergebnisse
# + Finanzplanung mit Zugriff auf Marktdaten
# + Beantwortung von Fragen zu Unternehmensinformationen

# %% [markdown]
# # 4 | Fine-Tuning
# ---

# %% [markdown]
# Fine-Tuning ist eine Methode, bei der ein bereits **trainiertes LLM** auf einer kleineren, **aufgabenspezifischen** Datenmenge weiter trainiert wird. Dadurch kann das Modell an **spezifische** **Anforderungen** angepasst und seine Leistung für diese Aufgaben verbessert werden.
#
# **Funktionsweise:**
#
# + Ein vortrainiertes LLM wird ausgewählt.
# + Eine aufgabenspezifische Datenmenge wird vorbereitet.
# + Das LLM wird auf dieser Datenmenge trainiert.
# + Die Parameter des LLM werden angepasst, um die Leistung für die spezifische Aufgabe zu optimieren.
#
#
# **Einsatzszenarien:**
#
# Fine-Tuning eignet sich besonders für Aufgaben, die eine hohe Genauigkeit und **Domänenspezialisierung** erfordern, wie z. B.:
#
# + fachlich spezialisierte LLMs (Recht, Medizin, ...)
# + Sentimentanalyse
# + Textklassifizierung
# + Spam-Erkennung
# + Personalisierte Kundeninteraktionen

# %% [markdown]
# # 5 | Entscheidungskriterien
# ---

# %% [markdown]
# Die Auswahl geeigneter Steuerungsmechanismen hängt wesentlich von den Anforderungen der jeweiligen KI-Anwendung ab. Einfache Aufgaben benötigen häufig nur einen klaren System-Prompt und passenden Kontext, während komplexere Anwendungen zusätzliche Mechanismen wie Fine-Tuning, Orchestrierung oder Qualitätskontrollen erfordern können.
#
# Wichtige Entscheidungskriterien sind dabei unter anderem die gewünschte Antwortqualität, Aktualität der Informationen, Datenschutzanforderungen, Kosten, Geschwindigkeit sowie die technische Komplexität des Systems. Zusätzliche Steuerungskomponenten können die Ergebnisse verbessern, erhöhen jedoch häufig auch Wartungsaufwand und Ressourcenverbrauch.
#
# In der Praxis entsteht daher meist eine Kombination verschiedener Mechanismen, die sich gegenseitig ergänzen und an die konkreten Ziele der Anwendung angepasst werden.

# %% [markdown]
# - [Modellsteuerung Decision Matrix](https://editor.p5js.org/ralf.bendig.rb/full/xb3zPgRSr)

# %% [markdown]
# # A | Aufgabe
# ---

# %% [markdown]
# <p><font color='darkblue' size="4">
# 📌 <b>Wichtig</b>
# </font></p>
#
# Die Aufgabestellungen unten bieten Anregungen — eigene Herausforderungen sind ausdrücklich willkommen.
#
# **Hinweis zur Lösungshilfe:**
# > Generative KI darf und soll im Kurs auch als Lernunterstützung genutzt werden — z. B. Gemini in Google Colab, um Fehlermeldungen zu verstehen, Teilschritte zu klären oder Code-Varianten zu prüfen.

# %% [markdown]
# **Grundlagen**
#
# Wähle ein eigenes Thema und formuliere denselben Prompt in drei Varianten: als direkte Frage, mit einer Rollenanweisung und mit einem konkreten Beispiel. Starte für jede Variante einen **neuen Gemini-Chat**, damit kein Kontext übertragen wird, und vergleiche die drei Antworten.
#
# **Gemini**
#
# > Variante 1 — direkte Frage: `Was ist ein Large Language Model?`
#
# **Gemini**
#
# > Variante 2 — mit Rollenanweisung: `Du bist ein KI-Experte. Was ist ein Large Language Model?`
#
# **Gemini**
#
# > Variante 3 — mit Beispiel: `Erkläre so wie für einen 12-Jährigen: Was ist ein Large Language Model?`
#
# **✅ Erledigt wenn:** Die drei Varianten liefern erkennbar unterschiedliche Antworten — Rollenanweisung und Beispiel zeigen messbaren Einfluss auf Ton oder Inhalt.

# %% [markdown]
# 💬 **Beobachtungen — Grundlagen**
#
# *Unterschiede zwischen den drei Varianten hier festhalten ...*

# %% [markdown]
# **Aufbau**
#
# Temperature steuert, wie kreativ oder präzise ein Modell antwortet. Da der Gemini-Chat keinen direkten Temperature-Regler bietet, simulierst du den Effekt durch gezielte Stil-Anweisungen. Stelle dreimal denselben Grundprompt — einmal neutral, einmal mit Präzisions-Anweisung, einmal mit Kreativitäts-Anweisung — und notiere Unterschiede in Länge, Ton und Struktur.
#
# **Gemini**
#
# > `Erkläre generative KI in zwei Sätzen.`
#
# **Gemini**
#
# > `Erkläre generative KI in exakt zwei Sätzen. Sei sachlich und präzise, kein Füllwort. (simuliert: niedrige Temperature)`
#
# **Gemini**
#
# > `Erkläre generative KI in zwei Sätzen. Sei kreativ und nutze eine Metapher aus dem Alltag. (simuliert: hohe Temperature)`
#
# **✅ Erledigt wenn:** Die drei Varianten unterscheiden sich erkennbar in Stil und Ton — die Kreativitäts-Anweisung erzeugt merklich andere Antworten als die Präzisions-Variante.

# %% [markdown]
# 💬 **Beobachtungen — Aufbau**
#
# *Unterschiede in Stil, Länge und Ton der drei Varianten hier festhalten ...*

# %% [markdown]
# **Vertiefung**
#
# Wähle zwei eigene Anwendungsfälle aus deinem Berufsalltag und besprich mit Gemini, welcher Steuerungsansatz besser passt. Fordere eine Begründung anhand der Kriterien aus der Modul-Tabelle ein (Komplexität, Datenbedarf, Effizienz).
#
# **Gemini**
#
# > Ich habe folgenden Anwendungsfall: [eigenen Anwendungsfall beschreiben]. Welcher Ansatz — Prompt Engineering, RAG oder Fine-Tuning — passt am besten? Begründe anhand von Komplexität, Datenbedarf und Effizienz.
#
# Falls die Antwort zu allgemein bleibt:
#
# **Gemini**
#
# > Warum nicht [anderer Ansatz] in diesem Fall? Nenne einen konkreten Nachteil.
#
# **✅ Erledigt wenn:** Für beide Fälle ist der gewählte Ansatz mit mindestens einem konkreten Kriterium aus der Modul-Tabelle begründet — keine pauschale Antwort.

# %% [markdown]
# 💬 **Beobachtungen — Vertiefung**
#
# *Anwendungsfall 1:*
# Beschreibung: ...
# Ansatz: ...
# Begründung: ...
#
# *Anwendungsfall 2:*
# Beschreibung: ...
# Ansatz: ...
# Begründung: ...

# %% [markdown]
# # B | Dokumente zum Weiterlesen
# ---

# %% [markdown]
# 📚 Ergänzende Artikel aus der Kurs-Dokumentation:
#
# - [Modellauswahl](https://ralf-42.github.io/GenAI/04-modelle-provider/modellauswahl.html)
# - [Provider-Modell-Mapping](https://ralf-42.github.io/GenAI/04-modelle-provider/provider-modell-mapping.html)
# - [Prompt Engineering](https://ralf-42.github.io/GenAI/05-prompting-rag/prompt-engineering.html)
# - [Context Engineering](https://ralf-42.github.io/GenAI/05-prompting-rag/context-engineering.html)
