# %% [markdown]
# <p><font size="6" color='grey'> <b>
#
# Generative KI. Verstehen. Anwenden. Gestalten.
# </b></font> </br></p>

# %% [markdown]
# <p><font size="5" color='grey'> <b>
# Agenten
# </b></font> </br></p>
#
#
# ---

# %%
#@title 🔧 Umgebung einrichten{ display-mode: "form" }
# !uv pip install --system -q git+https://github.com/ralf-42/GenAI.git#subdirectory=04_modul
from genai_lib.utilities import (
    check_environment,
    get_ipinfo,
    setup_api_keys,
    mprint,
    install_packages,
    mermaid,
    get_model_profile,
    extract_thinking,
    load_prompt
)
setup_api_keys(['OPENAI_API_KEY', 'SERPAPI_API_KEY'], create_globals=False)
print()
check_environment()
print()
get_ipinfo()

# ── Modell-Konfiguration ──────────────────────────────────────────────────────
from genai_lib.model_config import BASELINE, WORKER, PLANNER
# Out:
# ✓ OPENAI_API_KEY erfolgreich gesetzt
# ✓ SERPAPI_API_KEY erfolgreich gesetzt
#
# Python Version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
# Installierte LangChain- und LangGraph-Bibliotheken:
# langchain                                1.2.15
# langchain-chroma                         1.1.0
# langchain-classic                        1.0.4
# langchain-community                      0.4.1
# langchain-core                           1.3.1
# langchain-ollama                         1.1.0
# langchain-openai                         1.2.0
# langchain-text-splitters                 1.1.2
# langgraph                                1.1.9
# langgraph-checkpoint                     4.1.0
# langgraph-checkpoint-sqlite              3.1.0
# langgraph-prebuilt                       1.0.10
# langgraph-sdk                            0.3.13
#
# IP-Adresse: 34.142.206.33
# Hostname: 33.206.142.34.bc.googleusercontent.com
# Stadt: Singapore
# Region: Singapore
# Land: SG
# ...

# %%
#@title 🛠️ Installationen { display-mode: "form" }
install_packages([('google-search-results', 'serpapi'), 'wikipedia'])
# Out:
# 🔄 Installiere google-search-results...
# ✅ google-search-results erfolgreich installiert und importiert
# 🔄 Installiere wikipedia...
# ✅ wikipedia erfolgreich installiert und importiert

# %% [markdown]
# # 1 | Was ist ein echter Agent?
# ---

# %% [markdown]
# Wenn man sich mit generativer KI beschäftigt, stößt man früher oder später auf den Begriff **Agent** – also ein System, das Aufgaben eigenständig ausführt. Doch was genau ist ein *„echter“* Agent? Muss er vollständig autonom sein? Solche Fragen führen schnell zu Grundsatzdiskussionen – und genau das ist nicht hilfreich, wenn man einfach anfangen möchte, mit GenAI zu arbeiten.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ralf-42/GenAI/main/07_image/agentisch_1.png" class="logo" width="500"/>
# <p><font color='black' size="2">
# KI-generiertes Bild
# </font></p>

# %% [markdown]
# Ein praktischeren Vorschlag: Statt darüber zu diskutieren, ob etwas ein Agent ist oder nicht, sollten man lieber davon sprechen, wie **agentisch** ein System ist – also wie **selbstständig** es arbeitet. So kann man sich auf das konzentrieren, was wirklich zählt: Was kann das System leisten, und wo kann es sinnvoll eingesetzt werden?

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ralf-42/GenAI/main/07_image/agentisch_2.png" class="logo" width="900"/>

# %% [markdown]
# Besonders einfach ist der Einstieg bei eher einfachen Aufgaben – also bei Prozessen, die heute noch manuell erledigt werden, wie das Ausfüllen von Formularen, das Nachschlagen in einer Datenbank oder das Kopieren von Informationen zwischen verschiedenen Systemen. Diese Aufgaben lassen sich gut in sogenannte agentische Workflows überführen – also in Abläufe, bei denen die KI (teilweise) selbstständig handelt.
#
#
# Natürlich gibt es auch deutlich komplexere Anwendungen, bei denen die KI viele Entscheidungen trifft, Schleifen durchläuft und sich an neue Situationen anpasst. Solche Systeme sind spannend – aber gerade für den Anfang ist es oft sinnvoller, mit kleineren, überschaubaren Schritten zu starten. Dort liegen aktuell auch die meisten Chancen, GenAI im Alltag oder im Beruf sinnvoll einzusetzen.

# %% [markdown]
# **Beispiele:**
#
# | Autonomiegrad      | Entscheidungsspielraum                         | Beispielhafter Agent                             | Kontrolle | Vorhersagbarkeit | Konkreter Anwendungsfall                                                                                                                                      |
# |--------------------|------------------------------------------------|--------------------------------------------------|----------|------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Niedrig            | Keine – fester Ablauf                          | Skript mit harter Toolverkettung                | Hoch     | Voll             | Unterrichts-Agent, der immer: (1) feste Suchbegriffe zu „schwarzen Löchern" nutzt, <br>(2) definierte Seiten lädt und (3) aus diesen Quellen einen Aufsatz schreibt. |
# | Mittel (semi)      | Einige Entscheidungen erlaubt                  | Agent wählt Tools aus vordefinierter Liste      | Mittel   | Hoch bis mittel  | Recherche-Agent, der bei „Aufsatz über schwarze Löcher" selbst entscheidet, ob er <br>Websuche, News-Suche oder Papers (arXiv) nutzt und wie viele Seiten er lädt. |
# | Hoch               | Plant und handelt weitgehend selbstständig     | Agent erstellt Tools oder neue Strategien       | Niedrig  | Gering           | Forschungs-Agent, der nur das Ziel „aktuelle Übersicht zu schwarzer-Loch-Forschung" <br>bekommt, selbst Rechercheplan, Toolaufrufe und ggf. eigenen Parser-Code entwickelt. |

# %% [markdown]
# **Fazit:**
# Es muss nicht gleich ein „superintelligenter“ Agent sein. Besser ist es, pragmatisch zu denken, einfache Prozesse zu automatisieren – und so Schritt für Schritt Erfahrungen zu sammeln.

# %% [markdown]
# <br>
#
# **Agenten erweitern LLMs**
#
# Agenten kombinieren die Sprachfähigkeiten eines LLMs mit praktischer Handlungsfähigkeit. Das LLM übernimmt Sprachverständnis und logisches Schlussfolgern — der Agent ergänzt es durch Zugriff auf Tools wie Web, Datenbanken oder APIs. Der Denkprozess bleibt transparent: Wie der Agent zu einem Ergebnis kommt, ist nachvollziehbar. Anders als ein reines LLM trifft ein Agent iterative Entscheidungen — analysiert, plant und wählt zwischen Optionen, nicht nur einmal.

# %% [markdown]
# # 2 | Anatomie eines Agenten
# ---

# %% [markdown]
# **Was macht einen GenAI-Apps aus?**
#
# Ein Agent ist mehr als ein LLM mit Werkzeugen. Er arbeitet nicht nur reaktiv, sondern verfolgt Ziele, trifft Entscheidungen und passt sein Verhalten an. Um das zu erreichen, braucht er eine klar definierte Architektur – sonst bleibt er ein Tool-Controller statt ein intelligentes System.

# %% [markdown]
# **Die 6 Kernkomponenten eines Agenten**
#
# Diese Komponenten bilden ein vollständiges Agentenmodell. Fehlt eine davon, kommt der Agent schnell an seine Grenzen (z. B. endlose Schleifen, fehlende Zielorientierung, chaotische Tool-Nutzung).
#
# | Komponente                        | Rolle im Agenten                                                                |
# | --------------------------------- | ------------------------------------------------------------------------------- |
# | **1. Wahrnehmung (Perception)**   | Versteht Eingaben aus der Umgebung – Sprache, Sensoren, API-Ergebnisse.         |
# | **2. Ziel- & Aufgabenmanagement** | Verwaltet Ziele, priorisiert Aufgaben, kennt Abbruchkriterien.                  |
# | **3. Reasoning & Planung**        | Entwickelt Strategien, zerlegt Aufgaben und passt den Plan bei Fehlschlägen an. |
# | **4. Tools & Aktionen**           | Interagiert mit der Außenwelt – über APIs, Datenbanken, Code, Hardware etc.     |
# | **5. Gedächtnis & Kontext**       | Speichert Wissen, Verlauf und Zustände – kurzfristig oder langfristig.          |
# | **6. Monitoring & Feedback**      | Bewertet Handlungen, erkennt Fehlverhalten und optimiert Strategien.            |
#
# *Das LLM ist dabei **eine mögliche Komponente**, meist im Bereich Reasoning/Planung – aber es ist nicht der Agent selbst.*

# %% [markdown]
# **Der Denk- und Handlungszyklus**
#
# Ein Agent verarbeitet Informationen nicht linear wie ein LLM, sondern dynamisch und kontrolliert. Typischer Ablauf:
#
# 1. **Verstehen** → Eingabe interpretieren, Kontext bestimmen
# 2. **Ziel definieren / überprüfen**
# 3. **Plan entwickeln** → einzelne Schritte bestimmen
# 4. **Handeln** → Tools einsetzen, Daten abrufen, Aktionen durchführen
# 5. **Auswerten** → Erfolg/Misserfolg erkennen
# 6. **Lernen / Anpassen** → Strategie ändern oder Ziel neu formulieren
# 7. **Antwort geben oder weiterarbeiten**
#
# Dieser Zyklus kann mehrfach durchlaufen werden – oder dauerhaft aktiv bleiben (autonomer Modus).
#
#
# Ein Agent ist ein **entscheidungsfähiges System**, kein schnell zusammengebauter Prompt mit Tools. Erst wenn Zielmanagement, Gedächtnis, Feedback und Handlungskompetenz zusammenspielen, entsteht echte Intelligenz – und erst dann sind Agenten produktiv einsetzbar.

# %% [markdown]
# # 3 | Direkter Vergleich
# ---

# %% [markdown]
# <p><font color='black' size="5">
# 3.1 Setup und Tools
# </font></p>
#
# ---

# %% [markdown]
# Für den Vergleich werden zunächst die notwendigen Tools für den Agenten definiert. Diese Tools repräsentieren die erweiterten Fähigkeiten, die einem einfachen LLM fehlen.

# %% [markdown]
# Der `@tool`-Decorator aus langchain_core.tools wandelt normale Python-Funktionen automatisch in LangChain-Tools um, die Agents/LLMs aufrufen können. Er extrahiert Name (Funktionsname), Beschreibung (Docstring) und Parameter (Type-Hints/Signature) und erzeugt eine JSON-Schema-kompatible Tool-Definition.

# %%
#@markdown   <p><font size="4" color='green'>  Agenten-Tools</font> </br></p>

# ═══════════════════════════════════════════════════════════
# Tool-Definitionen
# ═══════════════════════════════════════════════════════════
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_community.utilities.serpapi import SerpAPIWrapper
from langchain_core.tools import tool
from serpapi import GoogleSearch
import io
import os
import sys

# ---- calculator
@tool
def calculator(expression: str) -> str:
    """Präzise mathematische Berechnungen durchführen.

    Args:
        expression: Mathematischer Ausdruck, z.B. '2847 * 1923'
    """
    try:
        if any(x in expression for x in ['import', 'exec', '__']):
            return "Unsichere Operation"
        result = eval(expression)
        return f"{expression} = {result}"
    except:
        return "Berechnungsfehler"

# ---- search
@tool
def search(query: str) -> str:
    """Aktuelle Informationen im Internet suchen (News, Fakten, Daten).

    Args:
        query: Suchbegriff in natürlicher Sprache
    """
    try:
        serpapi = SerpAPIWrapper(params={"engine": "google"})
        original_stdout = sys.stdout
        sys.stdout = io.StringIO()
        try:
            result = serpapi.run(query)
        finally:
            sys.stdout = original_stdout
        if not result or result.strip() == "":
            return f"Keine Suchergebnisse für '{query}' gefunden."
        return result
    except Exception as e:
        error_msg = str(e)
        if "JSONDecodeError" in error_msg or "Expecting value" in error_msg:
            return f"SerpAPI-Fehler: Leere oder ungültige API-Antwort für '{query}'."
        return f"Suchfehler für '{query}': {error_msg}"

def _search_fallback(query: str) -> str:
    """Interne Hilfsfunktion: Google-Suche ohne @tool-Wrapper."""
    try:
        serpapi = SerpAPIWrapper(params={"engine": "google"})
        return serpapi.run(query)
    except Exception as e:
        return f"Suchfehler: {str(e)}"

# ---- weather
@tool
def weather(city: str) -> str:
    """Aktuelle Wetterdaten einer Stadt abrufen (Temperatur, Luftfeuchtigkeit, Wind).

    Args:
        city: Name der Stadt, z.B. 'Berlin'
    """
    try:
        serpapi = SerpAPIWrapper(params={"engine": "google"})
        result = serpapi.run(f"Wetter in {city} Temperatur Luftfeuchtigkeit Luftdruck")
        return result
    except Exception as e:
        return f"Wetterfehler für {city}: {str(e)}"

# ---- stock_price
@tool
def stock_price(ticker: str) -> str:
    """Aktuelle Börsenkurse abrufen via Google Finance, mit Fallback auf Google-Suche.

    Args:
        ticker: Ticker im Format SYMBOL:BÖRSE, z.B. RHM:ETR (Rheinmetall XETRA),
                SAP:ETR (SAP), BMW:ETR (BMW), VOW3:ETR (VW), SIE:ETR (Siemens)
    """
    # 1. Versuch: Google Finance API
    try:
        params = {
            "engine": "google_finance",
            "q": ticker,
            "hl": "de",
            "api_key": os.environ.get("SERPAPI_API_KEY")
        }
        results = GoogleSearch(params).get_dict()

        if "error" not in results:
            summary = results.get("summary", {})
            price = summary.get("price")
            if price:
                currency = summary.get("currency", "")
                change = summary.get("price_change")
                change_pct = summary.get("price_change_percentage")
                stock_name = summary.get("title", ticker)
                exchange = summary.get("stock", ticker)
                parts = [f"{stock_name} ({exchange}): {price} {currency}"]
                if change is not None and change_pct is not None:
                    direction = "📈" if float(str(change).replace(",", ".")) >= 0 else "📉"
                    parts.append(f"{direction} {change} ({change_pct}%)")
                return " | ".join(parts)
    except Exception:
        pass  # Google Finance fehlgeschlagen → Fallback

    # 2. Fallback: reguläre Google-Suche
    symbol = ticker.split(":")[0]
    fallback_result = _search_fallback(f"{symbol} Aktie Kurs XETRA aktuell Euro heute")
    if fallback_result and "Suchfehler" not in fallback_result:
        return f"[via Suche] {fallback_result}"

    return f"Kurs für '{ticker}' nicht verfügbar (Google Finance und Suche fehlgeschlagen)."

# ---- read_file
@tool
def read_file(filename: str) -> str:
    """Datei vom Dateisystem lesen und Inhalt zurückgeben.

    Args:
        filename: Pfad zur Datei, z.B. 'notiz.txt'
    """
    try:
        with open(filename, 'r') as f:
            return f.read()
    except:
        return f"Datei {filename} nicht gefunden"

# ---- write_file
@tool
def write_file(filename: str, content: str) -> str:
    """Datei erstellen oder überschreiben mit angegebenem Inhalt.

    Args:
        filename: Pfad zur Datei, z.B. 'notiz.txt'
        content: Text-Inhalt der Datei
    """
    try:
        with open(filename, 'w', encoding='utf-8') as f:
            f.write(content)
        return f"Datei {filename} erfolgreich geschrieben."
    except Exception as e:
        return f"Fehler beim Schreiben der Datei: {str(e)}"

# ---- wiki
@tool
def wiki(term: str) -> str:
    """Einen Begriff in Wikipedia nachschlagen und Zusammenfassung abrufen.

    Args:
        term: Suchbegriff, z.B. 'Taylor Swift' oder 'Quantencomputer'
    """
    wiki_api = WikipediaAPIWrapper()
    try:
        return wiki_api.run(term)
    except Exception as e:
        return f"Wikipedia-Fehler: {e}"


# ═══════════════════════════════════════════════════════════
# Tool-Liste
# ═══════════════════════════════════════════════════════════
tools = [calculator, search, weather, stock_price, read_file, write_file, wiki]

mprint("✅ **Alle Tools definiert:**")
for t in tools:
    print(f" • {t.name:18s}:  {t.description.splitlines()[0]}")
# Out:
# ✅ **Alle Tools definiert:**
#  • calculator        :  Präzise mathematische Berechnungen durchführen.
#  • search            :  Aktuelle Informationen im Internet suchen (News, Fakten, Daten).
#  • weather           :  Aktuelle Wetterdaten einer Stadt abrufen (Temperatur, Luftfeuchtigkeit, Wind).
#  • stock_price       :  Aktuelle Börsenkurse abrufen via Google Finance, mit Fallback auf Google-Suche.
#  • read_file         :  Datei vom Dateisystem lesen und Inhalt zurückgeben.
#  • write_file        :  Datei erstellen oder überschreiben mit angegebenem Inhalt.
#  • wiki              :  Einen Begriff in Wikipedia nachschlagen und Zusammenfassung abrufen.

# %% [markdown]
# <p><font color='black' size="5">
# 3.2 Vergleichstest
# </font></p>
#
# ---

# %% [markdown]
# Wir verwenden eine Frage, die sowohl aktuelle Daten als auch eine Berechnung erfordert, um die Grenzen eines LLMs und die Stärken eines Agenten zu demonstrieren.

# %% [markdown]
# <p><font color='black' size="5">
# Basismodell
# </font></p>

# %%
# ── Stdlib ────────────────────────────────────────────────────────────────────
import time

# ── LangChain ─────────────────────────────────────────────────────────────────
from langchain.agents import create_agent
from langchain.chat_models import init_chat_model

# %%
# LLM (Kurznotation: "provider:model")
llm = init_chat_model(BASELINE)

# Test-Frage die Grenzen aufzeigt
test_question = "Wie ist das Wetter in Berlin, was ist 2847 * 1923, wie ist der heutige XETRA (in EURO) Kurs der Aktie von Rheinmetall? Halte dich konsequent an die zu beantwortenden Fragen."

# %% [markdown]
# <p><font color='black' size="5">
# LLM only
# </font></p>

# %%
# 1. EINFACHES LLM PROBIEREN
mprint("### 1️⃣ EINFACHES LLM:")
mprint("---")

start_time = time.time()
llm_response = llm.invoke(test_question)
llm_time = time.time() - start_time

mprint(f"**Antwort:** {llm_response.content}")
mprint(f"**Zeit:** {llm_time:.2f}s")
# Out:
# ### 1️⃣ EINFACHES LLM:
# ---
# **Antwort:** - **Wetter in Berlin:** Dafür brauche ich Live-Daten (Wetterdienst/Internet). Ich habe in diesem Chat keinen Zugriff auf aktuelle Wetterdaten. Wenn du mir einen Wetterdienst-Link oder den aktuellen Wetter-Text gibst, kann ich ihn auswerten.
# - **2847 × 1923:** **5.473.281**
# - **Heutiger XETRA-Kurs (in EUR) von Rheinmetall:** Dafür brauche ich ebenfalls Live-Daten (Börsenkurs/Internet). Ich kann den aktuellen Kurs nicht zuverlässig abrufen. Wenn du mir den Kurs-Link oder einen Screenshot/Text gibst, kann ich ihn dir direkt nennen bzw. bestätigen.
# **Zeit:** 2.85s

# %% [markdown]
# <p><font color='black' size="5">
# Agent
# </font></p>

# %%
# 2. AGENT MIT TOOLS
mprint("### 2️⃣ AGENT MIT TOOLS:")
mprint("---")

# Agent mit create_agent erstellen
agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt="""Du bist ein hilfreicher Agent. Beantworte ALLE Teile einer Frage vollständig.
Nutze für jede Teilfrage das passende Tool:
- weather: für Wetterdaten
- calculator: für Berechnungen
- stock_price: für Aktienkurse (Ticker im Format SYMBOL:BÖRSE, z.B. RHM:ETR)
- search: für sonstige aktuelle Informationen
Formatiere das Ergebnis im Markdown-Format, Formeln: $ Formel $""",
)

start_time = time.time()
agent_response = agent.invoke({"messages": [{"role": "user", "content": test_question}]})
agent_time = time.time() - start_time

mprint(f"## 🤖 KI-Agent: ")
mprint("---")
if isinstance(agent_response, dict) and 'messages' in agent_response:
    last_message = agent_response['messages'][-1]
    output = last_message.content if hasattr(last_message, 'content') else str(last_message)
else:
    output = str(agent_response)

mprint(f"{output}")
mprint(f"**Zeit:** {agent_time:.2f}s")
# Out:
# ### 2️⃣ AGENT MIT TOOLS:
# ---
# ## 🤖 KI-Agent:
# ---
# ## Wetter in Berlin
# - **Aktuell/Heute:** wolkig bis wechselnd bewölkt
# - **Temperatur (Beispiel-Angaben aus der Quelle):** ca. **4–12 °C** (je nach Zeitpunkt)
# - **Luftfeuchtigkeit:** ca. **89–100 %**
# - **Wind:** aus **SW**, etwa **7 km/h**
# - **Luftdruck:** ca. **1000–1023 hPa**
#
# ## 2847 * 1923
# - **$2847 \cdot 1923 = 5\,474\,781$**
#
# ## Rheinmetall (XETRA, EUR) – heutiger Kurs
# - **Rheinmetall (RHM:ETR, XETRA): € 1.209,60**
# **Zeit:** 93.80s

# %% [markdown]
# <p><font color='black' size="5">
# 3.3 Unterschiede
# </font></p>
#
# ---

# %% [markdown]
# Die Unterschiede zwischen LLM und Agent lassen sich in fünf Kernbereichen zusammenfassen, die den Paradigmenwechsel von statischer zu dynamischer KI verdeutlichen.
#
# **Vergleich der Fähigkeiten:**
#
# | Aspekt | Einfaches LLM | Agent |
# |--------|---------------|-------|
# | **Aktuelle Daten** | ❌ Nur Trainingsdaten | ✅ Über Tools |
# | **Berechnungen** | ⚠️ Oft ungenau | ✅ Präzise Tools |
# | **Externe APIs** | ❌ Unmöglich | ✅ Beliebig erweiterbar |
# | **Transparenz** | 🔒 Verborgen | 👁️ Sichtbar |
# | **Erweiterbarkeit** | ❌ Statisch | ✅ Modular |

# %% [markdown]
# **🎯 FAZIT:**
# - **Agent = LLM + Tools + Reasoning**
# - ➡️ Aus reaktiv wird proaktiv
# - ➡️ Aus statisch wird dynamisch
# - ➡️ Aus isoliert wird vernetzt

# %% [markdown]
# # 4 | Hands-On: Agent bauen
# ---

# %% [markdown]
# ⚠️ Debug-Hinweis
#
# <details>
#
#
# **Problem mit `debug=True` in Jupyter/Colab:**
#
# Der Parameter `debug=True` kann in Jupyter/Colab zu folgendem Fehler führen:
# ```
# AttributeError: 'OutStream' object has no attribute 'watch_fd_thread'
# ```
#
# **Ursache:** LangGraph's Debug-Output versucht, auf Output-Streams zuzugreifen, die in Jupyter nicht korrekt initialisiert sind.
#
# **Lösungen:**
# 1. **Einfachste Lösung:** `debug=True` entfernen oder auf `False` setzen
# 2. **Alternative:** `stream_mode="values"` statt `debug=True`:
#    ```python
#    for chunk in agent.stream(input, stream_mode="values"):
#        print(chunk)
#    ```
# 3. **Production:** LangSmith für professionelles Debugging verwenden
#
# </details>

# %%
#@markdown   <p><font size="4" color='green'>  Agent mit Tools-Architektur</font> </br></p>

diagram = """
# %%{init: {'theme':'forest'}}%%
graph TB
    A["User Input"] --> B["Agent Core<br/>LLM + Reasoning"]

    B --> C{Tool<br/>benötigt?}

    C -->|Datei lesen| D1["read_file"]
    C -->|Datei schreiben| D2["write_file"]
    C -->|Internet| D3["search"]
    C -->|Wikipedia| D4["wiki"]
    C -->|Aktienkurs| D5["stock_price"]
    C -->|Kein Tool| E["Direkte Antwort"]

    D1 --> F["Tool-Ergebnisse"]
    D2 --> F
    D3 --> F
    D4 --> F
    D5 --> F

    F --> G["LLM verarbeitet<br/>Ergebnisse"]
    G --> H["Finale Antwort"]
    E --> H

    I["Agent Scratchpad<br/>Gedächtnis"] -.-> B
    B -.-> I
    F -.-> I

    style A fill:#e1f5ff
    style B fill:#e1ffe1
    style C fill:#f0e1ff
    style D1 fill:#ffe1f5
    style D2 fill:#ffe1f5
    style D3 fill:#ffe1f5
    style D4 fill:#ffe1f5
    style D5 fill:#ffe1f5
    style E fill:#fff4e1
    style F fill:#fff4e1
    style G fill:#e1ffe1
    style H fill:#e1ffe1
    style I fill:#f0e1ff
"""
mermaid(diagram, width=900, height=600)
# Out:
# <div id="mermaid-d52b9d7e" style="width:900px; height:600px"><pre class="mermaid">
# %%{init: {'theme':'forest'}}%%
# graph TB
#     A["User Input"] --> B["Agent Core<br/>LLM + Reasoning"]
#
#     B --> C{Tool<br/>benötigt?}
#
#     C -->|Datei lesen| D1["read_file"]
#     C -->|Datei schreiben| D2["write_file"]
#     C -->|Internet| D3["search"]
#     C -->|Wikipedia| D4["wiki"]
#     C -->|Aktienkurs| D5["stock_price"]
#     C -->|Kein Tool| E["Direkte Antwort"]
#
#     D1 --> F["Tool-Ergebnisse"]
#     D2 --> F
#     D3 --> F
#     D4 --> F
#     D5 --> F
#
#     F --> G["LLM verarbeitet<br/>Ergebnisse"]
#     G --> H["Finale Antwort"]
#     E --> H
#
#     I["Agent Scratchpad<br/>Gedächtnis"] -.-> B
#     B -.-> I
#     F -.-> I
#
#     style A fill:#e1f5ff
#     style B fill:#e1ffe1
#     style C fill:#f0e1ff
#     style D1 fill:#ffe1f5
#     style D2 fill:#ffe1f5
#     style D3 fill:#ffe1f5
#     style D4 fill:#ffe1f5
#     style D5 fill:#ffe1f5
#     style E fill:#fff4e1
# ...

# %%
# Prompt als Template definieren
prompt = load_prompt("https://github.com/ralf-42/GenAI/blob/main/05_prompt/m08_agent_prompt.md")

# Modell
llm = init_chat_model(BASELINE)

# %%
# 🔧 Agenten-Logik
from datetime import date
today = date.today().strftime("%d.%m.%Y")

# System-Prompt als Markdown-Template laden (mode="S" → String)
system_prompt = load_prompt(
    "https://github.com/ralf-42/GenAI/blob/main/05_prompt/m08_tool_agent_system.md", mode="S"
).format(today=today)

# Agent mit create_agent erstellen (LangChain 1.0+ API)
custom_agent = create_agent(
    model=llm,
    tools=tools,
    system_prompt=system_prompt,
)

# %%
# 🔧 Test
input_text = f"""
Erstelle eine Datei 'notiz.txt' mit dem Inhalt 'Agenten können autonom agieren. 🤖'.
Wie ist der aktuelle XETRA Kurs der Aktie von Rheinmetall?
Lese die Datei 'notiz.txt' und verändere die Zeitform von Gegenwart in Zukunft.
Was ist die aktuelle Version von Python?
Was steht zu Taylor Swift auf Wikipedia.
"""

# ---------------⚠️ Workaround für Colab/Jupyter Stream-Problem -------------------------
# Redirecte stdout/stderr temporär, um OutStream-Fehler zu vermeiden
original_stdout = sys.stdout
original_stderr = sys.stderr
sys.stdout = io.StringIO()
sys.stderr = io.StringIO()

try:
    # Agent aufrufen mit korrektem Input-Format
    response = custom_agent.invoke({"messages": [{"role": "user", "content": input_text}]})
finally:
    # Stelle Original-Streams wieder her
    sys.stdout = original_stdout
    sys.stderr = original_stderr

# %%
mprint("## 🛠️ Hands-On Agent")
mprint("---")

# Extrahiere letzte Nachricht
if isinstance(response, dict) and 'messages' in response:
    last_message = response['messages'][-1]
    output = last_message.content if hasattr(last_message, 'content') else str(last_message)

    # Alle Messages anzeigen (um den Prozess zu sehen)
    mprint("### Agent-Verlauf:")
    for i, msg in enumerate(response['messages'], 1):
        role = getattr(msg, 'type', 'unknown')
        content_preview = str(msg.content if hasattr(msg, 'content') else msg)[:200]
        mprint(f"{i}. {role}: {content_preview}...")

    mprint("")
    mprint("### Finale Antwort:")
    mprint(output)
else:
    mprint("### Output:")
    mprint(str(response))
# Out:
# ## 🛠️ Hands-On Agent
# ---
# ### Agent-Verlauf:
# 1. human:
# Erstelle eine Datei 'notiz.txt' mit dem Inhalt 'Agenten können autonom agieren. 🤖'.
# Wie ist der aktuelle XETRA Kurs der Aktie von Rheinmetall?
# Lese die Datei 'notiz.txt' und verändere die Zeitform vo...
# 2. ai: ...
# 3. tool: Datei notiz.txt erfolgreich geschrieben....
# 4. tool: [via Suche] {'type': 'finance_results', 'title': 'Overview', 'exchange': 'ETR', 'stock': 'RHM', 'currency': 'EUR', 'price': 1209.6}...
# 5. tool: ['The main branch is currently the future Python 3.16, and is the only branch that accepts new features. The latest release for each Python version can be found ...', 'Active Python releases · 3.16 pr...
# 6. tool: Page: Taylor Swift
# Summary: Taylor Alison Swift (born December 13, 1989) is an American singer-songwriter. An influential figure in popular culture, she is known for her autobiographical songwriting a...
# 7. ai: ...
# 8. tool: Agenten können autonom agieren. 🤖...
# 9. ai: ...
# ...

# %% [markdown]
# # 5 | Agenten-Observability
# ---

# %% [markdown]
# Wenn ein Agent das falsche Ergebnis liefert, hilft die finale Antwort kaum weiter. Entscheidend ist, welche Tools in welcher Reihenfolge aufgerufen wurden, welche Inputs sie bekamen und was sie zurückgegeben haben.
#
# **Die drei Fragen, die jeder Agentenlauf beantworten können sollte:**
# - Welche Tools wurden in welcher Reihenfolge aufgerufen?
# - Was war die Eingabe an jedes Tool?
# - Wo ist der Agent von der erwarteten Route abgewichen?

# %%
# Tool-Calls aus den Agent-Messages extrahieren
zeilen = ["| Schritt | Typ | Tool / Inhalt |", "|---------|-----|---------------|"]

for i, msg in enumerate(response.get("messages", []), 1):
    typ = getattr(msg, "type", type(msg).__name__)

    if typ == "ai" and getattr(msg, "tool_calls", None):
        for tc in msg.tool_calls:
            args_preview = str(tc.get("args", {}))[:60]
            zeilen.append(f"| {i} | 🔧 Tool-Call | **{tc['name']}** → {args_preview} |")
    elif typ == "tool":
        inhalt = str(msg.content)[:60].replace("\n", " ")
        zeilen.append(f"| {i} | 📥 Ergebnis | {inhalt}… |")
    elif typ == "ai" and msg.content:
        inhalt = str(msg.content)[:60].replace("\n", " ")
        zeilen.append(f"| {i} | 🤖 LLM | {inhalt}… |")

mprint("\n".join(zeilen))
# Out:
# | Schritt | Typ | Tool / Inhalt |
# |---------|-----|---------------|
# | 2 | 🔧 Tool-Call | **write_file** → {'filename': 'notiz.txt', 'content': 'Agenten können autonom |
# | 2 | 🔧 Tool-Call | **stock_price** → {'ticker': 'RHM:ETR'} |
# | 2 | 🔧 Tool-Call | **search** → {'query': 'aktuelle Version von Python'} |
# | 2 | 🔧 Tool-Call | **wiki** → {'term': 'Taylor Swift'} |
# | 3 | 📥 Ergebnis | Datei notiz.txt erfolgreich geschrieben.… |
# | 4 | 📥 Ergebnis | [via Suche] {'type': 'finance_results', 'title': 'Overview',… |
# | 5 | 📥 Ergebnis | ['The main branch is currently the future Python 3.16, and i… |
# | 6 | 📥 Ergebnis | Page: Taylor Swift Summary: Taylor Alison Swift (born Decemb… |
# | 7 | 🔧 Tool-Call | **read_file** → {'filename': 'notiz.txt'} |
# | 8 | 📥 Ergebnis | Agenten können autonom agieren. 🤖… |
# | 9 | 🔧 Tool-Call | **write_file** → {'filename': 'notiz.txt', 'content': 'Agenten können autonom |
# | 10 | 📥 Ergebnis | Datei notiz.txt erfolgreich geschrieben.… |
# ...

# %%
# Optional: LangSmith-Trace für detaillierteres Debugging
# Voraussetzung: LANGSMITH_TRACING="true" in der Setup-Zelle konfiguriert
import os

if os.environ.get("LANGSMITH_TRACING") == "true":
    from genai_lib.utilities import show_trace
    show_trace("M10-Agenten", show_steps=True)
else:
    mprint("💡 **Tipp:** Für schrittweises Tracing `LANGSMITH_TRACING='true'` in `setup_api_keys()` aktivieren — "
           "dann zeigt `show_trace()` jeden LLM- und Tool-Aufruf mit Latenzen und Tokenzahlen.")
# Out:
# 💡 **Tipp:** Für schrittweises Tracing `LANGSMITH_TRACING='true'` in `setup_api_keys()` aktivieren — dann zeigt `show_trace()` jeden LLM- und Tool-Aufruf mit Latenzen und Tokenzahlen.

# %% [markdown]
# **Wann reicht `print`, wann braucht man Tracing?**
#
# | Situation | Empfehlung |
# |-----------|------------|
# | Einzelner Test im Notebook | Message-Loop oben reicht |
# | Agent läuft falsch, Ursache unklar | LangSmith Trace (jeder Schritt sichtbar) |
# | Mehrere Varianten vergleichen | LangSmith Datasets + Evaluation |
# | Produktionssystem mit vielen Anfragen | LangSmith Monitoring + Alerts |
#
# In der Praxis relevant wenn: Ein Agent in einer Schleife hängt, das falsche Tool wählt oder eine unerwartete Antwort produziert. Der erste Schritt ist immer: jeden einzelnen Schritt sichtbar machen.

# %% [markdown]
# # 6 | Agenten-Kette
# ---

# %% [markdown]
# Ein einzelner Agent mit vielen Tools stößt bei komplexen Aufgaben schnell an Grenzen: Der System-Prompt wird unübersichtlich, die Tool-Auswahl fehleranfällig, und die Verantwortlichkeiten verschwimmen.
#
# Die Lösung: **Spezialisierte Agenten**, die jeweils nur eine Aufgabe beherrschen – und ein **Supervisor-Agent**, der die Arbeit verteilt.
#
# Das Prinzip ist einfach: Jeder Spezialist wird als `@tool` verpackt und kann vom Supervisor wie ein normales Tool aufgerufen werden. So entsteht eine sequentielle Kette ohne zusätzliche Frameworks.

# %%
#@markdown   <p><font size="4" color='green'>  Agenten-Kette</font> </br></p>

diagram = """
# %%{init: {'theme':'forest'}}%%
graph LR
    A["<b>User</b>"] --> B["<b>Supervisor</b>"]

    B -->|Recherche| C["<b>Recherche-Agent</b><br/>search, wiki"]
    B -->|Analyse| D["<b>Analyse-Agent</b><br/>calculator, read_file"]
    B -->|Report| E["<b>Report-Agent</b><br/>write_file"]

    C -->|Ergebnis| B
    D -->|Ergebnis| B
    E -->|Ergebnis| B

    B --> F["<b>Finale Antwort</b>"]

    style A fill:#e1f5ff
    style B fill:#e1ffe1
    style C fill:#ffe1f5
    style D fill:#ffe1f5
    style E fill:#ffe1f5
    style F fill:#fff4e1
"""
mermaid(diagram, width=800, height=350)
# Out:
# <div id="mermaid-84637a47" style="width:800px; height:350px"><pre class="mermaid">
# %%{init: {'theme':'forest'}}%%
# graph LR
#     A["<b>User</b>"] --> B["<b>Supervisor</b>"]
#
#     B -->|Recherche| C["<b>Recherche-Agent</b><br/>search, wiki"]
#     B -->|Analyse| D["<b>Analyse-Agent</b><br/>calculator, read_file"]
#     B -->|Report| E["<b>Report-Agent</b><br/>write_file"]
#
#     C -->|Ergebnis| B
#     D -->|Ergebnis| B
#     E -->|Ergebnis| B
#
#     B --> F["<b>Finale Antwort</b>"]
#
#     style A fill:#e1f5ff
#     style B fill:#e1ffe1
#     style C fill:#ffe1f5
#     style D fill:#ffe1f5
#     style E fill:#ffe1f5
#     style F fill:#fff4e1
# </pre></div>
# <script type="module">
#     // Mermaid einmalig laden und in window._mermaidLib cachen.
#     // Bei schnellem "Run All" vermeidet das Race Conditions durch parallele CDN-Requests.
#     if (!window._mermaidLib) {
#         const m = await import('https://cdn.jsdelivr.net/npm/mermaid@11/dist/mermaid.esm.min.mjs');
# ...

# %% [markdown]
# <p><font color='black' size="5">
# 6.1 Spezialisierte Agenten definieren
# </font></p>
#
# ---

# %% [markdown]
# Jeder Agent erhält nur die Tools, die er für seine Aufgabe braucht, und einen fokussierten System-Prompt. So bleibt jeder Agent schlank und zuverlässig.

# %%
# ═══════════════════════════════════════════════════════════
# 🔍 Spezialist 1: Recherche-Agent
# ═══════════════════════════════════════════════════════════

recherche_agent = create_agent(
    model=WORKER,
    tools=[search, wiki],
    system_prompt="""Du bist ein Recherche-Spezialist. Deine Aufgabe:
- Nutze 'search' für aktuelle Informationen (News, Fakten, Daten).
- Nutze 'wiki' für Hintergrundwissen und Definitionen.
- Fasse die gefundenen Informationen strukturiert zusammen.
- Gib immer die Quelle an (Web-Suche oder Wikipedia)."""
)

@tool
def recherche(frage: str) -> str:
    """Recherchiert Informationen zu einer Frage über Web-Suche und Wikipedia.

    Args:
        frage: Die zu recherchierende Frage oder ein Suchbegriff
    """
    original_stdout, original_stderr = sys.stdout, sys.stderr
    sys.stdout = io.StringIO()
    sys.stderr = io.StringIO()
    try:
        result = recherche_agent.invoke(
            {"messages": [{"role": "user", "content": frage}]}
        )
    finally:
        sys.stdout = original_stdout
        sys.stderr = original_stderr

    return result["messages"][-1].content

print("✅ Recherche-Agent definiert (Tools: search, wiki)")
# Out:
# ✅ Recherche-Agent definiert (Tools: search, wiki)

# %%
from genai_lib.model_config import WORKER
# ═══════════════════════════════════════════════════════════
# 📊 Spezialist 2: Analyse-Agent
# ═══════════════════════════════════════════════════════════

analyse_agent = create_agent(
    model=WORKER,
    tools=[calculator, stock_price, weather],
    system_prompt="""Du bist ein Analyse-Spezialist. Deine Aufgabe:
- Nutze 'calculator' für präzise mathematische Berechnungen.
- Nutze 'stock_price' für Börsenkurse (Ticker: SYMBOL:BÖRSE, z.B. RHM:ETR).
- Nutze 'weather' für aktuelle Wetterdaten.
- Präsentiere Zahlen und Ergebnisse klar und übersichtlich."""
)

@tool
def analyse(auftrag: str) -> str:
    """Analysiert Daten: Berechnungen, Aktienkurse oder Wetterdaten.

    Args:
        auftrag: Beschreibung der gewünschten Analyse
    """
    original_stdout, original_stderr = sys.stdout, sys.stderr
    sys.stdout = io.StringIO()
    sys.stderr = io.StringIO()
    try:
        result = analyse_agent.invoke(
            {"messages": [{"role": "user", "content": auftrag}]}
        )
    finally:
        sys.stdout = original_stdout
        sys.stderr = original_stderr

    return result["messages"][-1].content

print("✅ Analyse-Agent definiert (Tools: calculator, stock_price, weather)")
# Out:
# ✅ Analyse-Agent definiert (Tools: calculator, stock_price, weather)

# %%
# ═══════════════════════════════════════════════════════════
# ✍️ Spezialist 3: Report-Agent
# ═══════════════════════════════════════════════════════════

REPORT_PATH = "rheinmetall_report.md"

@tool
def save_report(content: str) -> str:
    """Markt-Report unter dem festen Kurs-Dateinamen speichern.

    Args:
        content: Markdown-Inhalt des Reports
    """
    try:
        with open(REPORT_PATH, "w", encoding="utf-8") as f:
            f.write(content)
        return f"Report erfolgreich gespeichert: {REPORT_PATH}"
    except Exception as e:
        return f"Fehler beim Speichern des Reports: {str(e)}"

report_agent = create_agent(
    model=WORKER,
    tools=[save_report, read_file],
    system_prompt="""Du bist ein Report-Spezialist. Deine Aufgabe:
- Erstelle aus den gelieferten Informationen einen gut strukturierten Bericht.
- Nutze ausschließlich 'save_report', um den Bericht zu speichern.
- Erfinde keinen eigenen Dateinamen. Das Tool gibt den tatsächlich gespeicherten Dateinamen zurück.
- Nenne den vom Tool zurückgegebenen Dateinamen in deiner finalen Antwort.
- Nutze 'read_file' um bestehende Dateien zu lesen falls nötig.
- Formatiere den Bericht mit Markdown (Überschriften, Listen, Tabellen)."""
)

@tool
def report(auftrag: str) -> str:
    """Einen strukturierten Markdown-Report erstellen und speichern.

    Args:
        auftrag: Beschreibung des gewünschten Reports inklusive aller Daten
    """
    try:
        result = report_agent.invoke(
            {"messages": [{"role": "user", "content": auftrag}]}
        )
        final_answer = result["messages"][-1].content

        # Die Tool-Ausgabe ist die verlässliche Quelle für den tatsächlichen Dateinamen.
        saved_report = None
        for msg in result.get("messages", []):
            if getattr(msg, "type", None) == "tool" and getattr(msg, "name", None) == "save_report":
                saved_report = str(msg.content)

        if saved_report and REPORT_PATH not in final_answer:
            final_answer += f"\n\nGespeicherte Datei: `{REPORT_PATH}`"
        return final_answer
    except Exception as e:
        return f"Report-Fehler: {str(e)}"

print("✅ Report-Agent definiert (speichert fest nach rheinmetall_report.md)")
# Out:
# ✅ Report-Agent definiert (speichert fest nach rheinmetall_report.md)

# %% [markdown]
# <p><font color='black' size="5">
# 6.2 Supervisor-Agent
# </font></p>
#
# ---

# %% [markdown]
# Der Supervisor kennt die drei Spezialisten als Tools und entscheidet selbst, welchen er in welcher Reihenfolge aufruft. Er orchestriert die Kette und fasst am Ende alles zusammen.

# %%
# ═══════════════════════════════════════════════════════════
# 🎯 Supervisor-Agent
# ═══════════════════════════════════════════════════════════

supervisor = create_agent(
    model=PLANNER,
    tools=[recherche, analyse, report],
    system_prompt="""Du bist ein Supervisor-Agent, der komplexe Aufgaben koordiniert.
Du hast drei spezialisierte Agenten als Tools:

1. 'recherche' → für Faktensuche, Hintergrundinformationen, Wikipedia
2. 'analyse' → für Berechnungen, Aktienkurse, Wetterdaten
3. 'report' → für das Erstellen und Speichern von strukturierten Berichten

Arbeitsweise:
- Zerlege die Aufgabe in Teilschritte.
- Delegiere jeden Teilschritt an den passenden Spezialisten.
- Fasse die Ergebnisse aller Spezialisten zusammen.
- Antworte auf Deutsch im Markdown-Format."""
)

print("✅ Supervisor-Agent erstellt (delegiert an: recherche, analyse, report)")
# Out:
# ✅ Supervisor-Agent erstellt (delegiert an: recherche, analyse, report)

# %% [markdown]
# <p><font color='black' size="5">
# 6.3 Test: Komplexe Aufgabe delegieren
# </font></p>
#
# ---

# %% [markdown]
# Jetzt testen wir den Supervisor mit einer Aufgabe, die alle drei Spezialisten erfordert: Recherche (Wikipedia), Analyse (Aktienkurs + Berechnung) und Report (Datei schreiben).

# %%
# ═══════════════════════════════════════════════════════════
# 🧪 Test: Supervisor delegiert an Spezialisten
# ═══════════════════════════════════════════════════════════

aufgabe = """
Erstelle einen kurzen Markt-Report für Rheinmetall:
1. Recherchiere Hintergrundinformationen zu Rheinmetall auf Wikipedia.
2. Hole den aktuellen XETRA-Kurs (Ticker: RHM:ETR).
3. Berechne, wie viel 150 Aktien zum aktuellen Kurs wert wären.
4. Speichere den Bericht unter dem festen Dateinamen 'rheinmetall_report.md'.
5. Gib den tatsächlich gespeicherten Dateinamen in der Antwort zurück.
"""

# Supervisor aufrufen
original_stdout, original_stderr = sys.stdout, sys.stderr
sys.stdout = io.StringIO()
sys.stderr = io.StringIO()

try:
    start_time = time.time()
    result = supervisor.invoke(
        {"messages": [{"role": "user", "content": aufgabe}]}
    )
    elapsed = time.time() - start_time
finally:
    sys.stdout = original_stdout
    sys.stderr = original_stderr

# Ergebnis anzeigen
mprint("## 🎯 Supervisor-Ergebnis")
mprint("---")

if isinstance(result, dict) and "messages" in result:
    # Delegations-Verlauf zeigen
    mprint("### Delegations-Verlauf:")
    for i, msg in enumerate(result["messages"], 1):
        role = getattr(msg, "type", "unknown")
        if role == "tool":
            name = getattr(msg, "name", "?")
            content_preview = str(msg.content)[:150]
            mprint(f"  {i}. 🔧 **{name}**: {content_preview}...")
        elif role == "ai" and hasattr(msg, "tool_calls") and msg.tool_calls:
            calls = [tc["name"] for tc in msg.tool_calls]
            mprint(f"  {i}. 🤖 Supervisor → delegiert an: **{', '.join(calls)}**")

    mprint("")
    mprint("### Finale Antwort:")
    mprint(result["messages"][-1].content)
else:
    mprint(str(result))

mprint(f"\n**Zeit:** {elapsed:.1f}s")
# Out:
# ## 🎯 Supervisor-Ergebnis
# ---
# ### Delegations-Verlauf:
#   2. 🤖 Supervisor → delegiert an: **recherche, analyse**
#   3. 🔧 **recherche**: Hier sind die wichtigsten **Wikipedia-Hintergrundinformationen zu Rheinmetall**:
#
# ## Unternehmensprofil
# - **Rheinmetall AG** ist ein **deutscher Autom...
#   4. 🔧 **analyse**: Hier sind die aktuellen Daten für **Rheinmetall (RHM:ETR)**:
#
# - **Kurs:** 1.209,60
# - **Währung:** EUR
# - **Zeitpunkt:** aktuell abgerufen
# - **Wert von ...
#   5. 🤖 Supervisor → delegiert an: **report**
#   6. 🔧 **report**: Der Report wurde erfolgreich gespeichert unter **rheinmetall_report.md**....
# ### Finale Antwort:
# # Markt-Report Rheinmetall
#
# Ich habe den kurzen Report erstellt und gespeichert.
#
# ## Kurzinhalt
# ...

# %%
# Gespeicherten Report anzeigen
report_path = globals().get("REPORT_PATH", "rheinmetall_report.md")

try:
    with open(report_path, "r", encoding="utf-8") as f:
        content = f.read()
    mprint(f"### 📄 Gespeicherter Report (`{report_path}`):")
    mprint("---")
    mprint(content)
except FileNotFoundError:
    mprint(f"⚠️ Report-Datei `{report_path}` wurde nicht erstellt.")
# Out:
# ### 📄 Gespeicherter Report (`rheinmetall_report.md`):
# ---
# # Markt-Report Rheinmetall
#
# ## Hintergrund (Wikipedia)
# - Rheinmetall AG ist ein deutscher Automobil- und Rüstungskonzern.
# - Sitz: Düsseldorf, Nordrhein-Westfalen, Deutschland.
# - Schwerpunkte: militärische Systeme und Fahrzeugtechnik, darunter gepanzerte Fahrzeuge, Artilleriesysteme, Luftverteidigung, Panzerabwehrwaffen, Munition und Marine-Anwendungen.
# - Einordnung: größter deutscher und fünftgrößter europäischer Rüstungskonzern.
# - Seit März 2023 im DAX vertreten.
#
# ## Aktueller XETRA-Kurs
# - Ticker: RHM:ETR
# - Kurs: 1.209,60 EUR
#
# ## Bewertungsrechnung
# - Anzahl Aktien: 150
# - Gesamtwert: 181.440,00 EUR
#
# ## Hinweis
# - Kurs stand zum Zeitpunkt des Abrufs.

# %% [markdown]
# <p><font color='black' size="5">
# 6.4 Vergleich: Ein Agent vs. Agenten-Kette
# </font></p>
#
# ---

# %% [markdown]
# | Aspekt | Ein Agent mit allen Tools | Supervisor + Spezialisten |
# |--------|--------------------------|---------------------------|
# | **System-Prompt** | Lang und komplex | Kurz und fokussiert pro Agent |
# | **Tool-Auswahl** | Agent muss aus vielen Tools wählen | Jeder Spezialist hat nur 2-3 Tools |
# | **Fehlersuche** | Schwer nachvollziehbar | Klar: welcher Spezialist hat was gemacht? |
# | **Erweiterbarkeit** | Prompt wird immer länger | Neuen Spezialisten als `@tool` hinzufügen |
# | **Kosten** | Weniger API-Calls | Mehr API-Calls (mehrere Agenten) |
#
# **Wann welchen Ansatz?**
# - **Ein Agent reicht** für einfache Aufgaben mit 2-5 Tools
# - **Agenten-Kette** lohnt sich bei 6+ Tools oder klar trennbaren Verantwortlichkeiten
# - Für **Zyklen**, **Shared State** oder **Conditional Routing** → LangGraph (siehe Kurs „Agenten")

# %% [markdown]
# # 7 | Wann braucht man Agenten?
# ---

# %% [markdown]
# Die Entscheidung zwischen einem einfachen LLM und einem Agenten hängt von den Anforderungen der Aufgabe ab. Eine klare Entscheidungsmatrix hilft, die richtige Technologie für den jeweiligen Anwendungsfall zu wählen und Ressourcen effizient einzusetzen.

# %% [markdown]
# Die Wahl der richtigen Technologie beginnt mit der Analyse der Aufgabenanforderungen. Während LLMs für viele Textverarbeitungsaufgaben ausreichen, sind Agenten unverzichtbar, wenn externe Interaktionen oder aktuelle Daten benötigt werden.
#
# **Ein Agent ist sinnvoll, wenn** aktuelle oder dynamische Daten benötigt werden (Aktienkurse, Wetter, Nachrichten), präzise Berechnungen erforderlich sind, externe Systeme wie Datenbanken oder APIs angesprochen werden müssen, oder komplexe mehrstufige Prozesse durchgeführt werden sollen, bei denen jeder Schritt vom vorherigen abhängt.
#
# **Ein einfaches LLM reicht, wenn** reine Textverarbeitung ohne externe Daten im Fokus steht — also Zusammenfassungen, Übersetzungen, Textanalysen oder kreative Aufgaben. Auch für statische Code-Generierung ohne externe Abhängigkeiten sind LLMs sehr effektiv.
#
# <br>
#
# **Die Faustregel lautet**:
# Wenn Tools, aktuelle Daten oder externe Interaktionen benötigt werden, ist ein Agent die richtige Wahl. Für reine Textverarbeitung reicht ein LLM aus.

# %% [markdown]
# # A | Aufgabe
# ---

# %% [markdown]
# <p><font color='darkblue' size="4">
# 📌 <b>Wichtig</b>
# </font></p>
#
# Die Aufgabestellungen unten bieten Anregungen — eigene Herausforderungen sind ausdrücklich willkommen.
#
# **Hinweis zur Lösungshilfe:**
# > In diesem Kurs darf und soll generative KI auch als Unterstützung beim Lernen und Entwickeln genutzt werden. Bei einer Aufgabe, bei der man festhängt, kann zum Beispiel Gemini in Google Colab helfen: Fehlermeldungen besser verstehen, Ideen für Teilschritte entwickeln oder Code-Varianten prüfen.
# > Wichtig ist: Die KI dient als Lern- und Entwicklungshilfe. Der Schwerpunkt des Kurses bleibt darauf, GenAI-Apps selbst zu verstehen, aufzubauen und gezielt weiterzuentwickeln.

# %% [markdown]
# **Grundlagen**
#
# Baue einen Agenten mit einem Rechentool und löse drei einzelne Gleichungen (z.B. aus einer Liste).
#
# **✅ Erledigt wenn:** Alle drei Gleichungen werden korrekt gelöst — die Ergebnisse sind manuell geprüft.

# %%
# Grundlagen: Agent mit Rechentool, 3 Gleichungen lösen
# Startpunkt: Agent-Beispiel aus Kapitel 3 als Vorlage

gleichungen = [
    "2 * x + 5 = 11",
    "x^2 - 4 = 0",
    "3 * x - 9 = 0",
]

# ...

# %% [markdown]
# **Aufbau**
#
# Verarbeite eine vollständige Gleichungsdatei und speichere die Ergebnisse strukturiert (z.B. als Liste oder CSV).
#
# **✅ Erledigt wenn:** Die Ausgabedatei enthält für jede Gleichung Eingabe und Ergebnis und lässt sich mit `pd.read_csv()` fehlerfrei einlesen.

# %%
# Aufbau: Gleichungsdatei verarbeiten und als CSV speichern
# Startpunkt: gleichungen.txt aus 02_daten verwenden

import csv

# 1. Gleichungsdatei einlesen
# 2. Agent für jede Zeile aufrufen
# 3. Ergebnisse in CSV speichern

ergebnisse = []  # Liste mit (gleichung, ergebnis)-Tupeln

# ...

# %% [markdown]
# **Vertiefung**
#
# Baue Fehlerbehandlung für ungültige Eingaben ein, ergänze Logging oder füge ein zweites Tool für Dateiverarbeitung oder Validierung hinzu.
#
# **✅ Erledigt wenn:** Bei ungültiger Eingabe gibt der Agent eine verständliche Fehlermeldung aus — kein unbehandelter Exception-Trace in der Ausgabe.

# %%
# Vertiefung: Fehlerbehandlung + Logging + zweites Tool

# Option A: Fehlerbehandlung
#   Teste mit ungültigen Eingaben: 'abc', '', '1/0'
#   try/except im Tool oder im Agenten-Aufruf

# Option B: Logging
#   Jeder Tool-Aufruf soll Eingabe + Ergebnis + Zeitstempel loggen

# Option C: Zweites Tool
#   z.B. Tool das prüft ob eine Zahl eine Primzahl ist
# ...
